# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df11 = pd.read_excel("乡风文明.xlsx",sheet_name=0,header=1)
df12 = pd.read_excel("乡风文明.xlsx",sheet_name=1,header=1)
df21 = pd.read_excel("产业兴旺.xlsx",sheet_name=0,header=1)
df22 = pd.read_excel("产业兴旺.xlsx",sheet_name=1,header=1)
df31 = pd.read_excel("生态宜居.xlsx",sheet_name=0,header=1)
df32 = pd.read_excel("生态宜居.xlsx",sheet_name=1,header=1)
df33 = pd.read_excel("生态宜居.xlsx",sheet_name=2,header=1)
df41 = pd.read_excel("治理有效.xlsx",sheet_name=0,header=1)
df42 = pd.read_excel("治理有效.xlsx",sheet_name=1,header=1)
df43 = pd.read_excel("治理有效.xlsx",sheet_name=2,header=1)
df51 = pd.read_excel("生活富裕.xlsx",sheet_name=0,header=1)
df52 = pd.read_excel("生活富裕.xlsx",sheet_name=1,header=1)
df53 = pd.read_excel("生活富裕.xlsx",sheet_name=2,header=1)
df11.head(10)
# Out:
#     地区   2017   2018   2019   2020   2021
# 0   北京   2696   2493   2449   2472   2559
# 1   天津   2541   2511   2374   2196   2214
# 2   河北  60225  59047  59526  60183  59967
# 3   山西  28942  28338  28106  26800  26355
# 4  内蒙古  13625  13539  13321  13030  12965
# 5   辽宁  19519  19127  17963  17567  16235
# 6   吉林  10108   9901   9615   9638   9463
# 7  黑龙江  10842  10740  10448  10385  10128
# 8   上海   1187   1162   1179   1169   1147
# 9   江苏  15319  15311  15169  15020  14936

# %%
import numpy as np
from sklearn import preprocessing
df11 = df11.drop(['地区'],axis=1)
normalized_data11 = preprocessing.normalize(df11, axis=0)
print(normalized_data11)
# Out:
# [[0.01835263 0.01722406 0.01700179 0.01730471 0.01818124]
#  [0.01729749 0.01734842 0.01648112 0.01537263 0.01573007]
#  [0.40997307 0.40795383 0.41324974 0.42129825 0.4260548 ]
#  [0.19701853 0.19578633 0.19512141 0.18760768 0.18724756]
#  [0.09275024 0.09354052 0.09247891 0.09121374 0.092114  ]
#  [0.1328728  0.13214783 0.12470526 0.12297404 0.11534677]
#  [0.06880876 0.06840569 0.0667506  0.06746876 0.06723292]
#  [0.07380536 0.07420232 0.07253357 0.07269798 0.07195763]
#  [0.00808033 0.00802822 0.00818502 0.00818334 0.00814923]
#  [0.1042819  0.10578321 0.10530836 0.10514431 0.10611761]
#  [0.07852286 0.07933568 0.08046172 0.07910324 0.0797232 ]
#  [0.10436359 0.10582466 0.10794645 0.1099745  0.11104835]
#  [0.1266713  0.12631666 0.12215742 0.11984491 0.11969492]
#  [0.20240995 0.19558597 0.19499645 0.19208787 0.19317298]
#  [0.3609533  0.36787491 0.3725468  0.37467634 0.37612922]
#  [0.38435699 0.38809745 0.38931949 0.39903734 0.41554677]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df12 = df12.drop(['地区'],axis=1)
normalized_data12 = preprocessing.normalize(df12, axis=0)
print(normalized_data12)
# Out:
# [[0.12205532 0.11737317 0.12129426 0.10946511 0.10456511]
#  [0.12742039 0.12067946 0.11733902 0.10021453 0.12318629]
#  [0.14888067 0.17027375 0.16743882 0.16188502 0.16472585]
#  [0.21862657 0.20664291 0.19380714 0.17267735 0.16759065]
#  [0.2092377  0.22648062 0.19776239 0.19272026 0.18191464]
#  [0.18777742 0.19176462 0.18325981 0.16342678 0.18621183]
#  [0.20387263 0.21490862 0.20830971 0.18192792 0.21056261]
#  [0.19582503 0.20498976 0.21226496 0.17113559 0.17045545]
#  [0.11400772 0.09753545 0.10415486 0.08325515 0.08164673]
#  [0.14888067 0.15374232 0.15029941 0.16034326 0.15326666]
#  [0.1475394  0.15043604 0.17534932 0.16034326 0.16329345]
#  [0.16095208 0.16531432 0.16480199 0.1788444  0.20196822]
#  [0.14619814 0.15043604 0.16216516 0.1464674  0.16186105]
#  [0.17972982 0.17358004 0.19117031 0.21738845 0.21199501]
#  [0.17168221 0.18515204 0.17798615 0.18346969 0.17332024]
#  [0.17838855 0.1950709  0.20039922 0.19580378 0.20626541]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df21 = df21.drop(['地区'],axis=1)
normalized_data21 = preprocessing.normalize(df21, axis=0)
print(normalized_data21)
# Out:
# [[0.00257452 0.00214314 0.00178917 0.00188454 0.00229173]
#  [0.01329019 0.01316332 0.01388848 0.014085   0.01516912]
#  [0.23974873 0.23232207 0.23261972 0.23431104 0.23221381]
#  [0.0848426  0.08665483 0.08471816 0.08791672 0.08628134]
#  [0.20376623 0.22305771 0.22722608 0.22617596 0.23313718]
#  [0.14592726 0.13763139 0.15116823 0.14437028 0.15412199]
#  [0.26008128 0.22804582 0.24124769 0.23476041 0.24521444]
#  [0.46396021 0.47124054 0.46676547 0.46547397 0.47763405]
#  [0.00624721 0.00651229 0.00596536 0.00564437 0.00570413]
#  [0.22607161 0.22977465 0.23056429 0.23018578 0.22741848]
#  [0.03632247 0.03761111 0.03683791 0.03738838 0.03769364]
#  [0.2516734  0.25155575 0.25220108 0.24809665 0.24814786]
#  [0.03050038 0.03129844 0.03072573 0.03100699 0.03074378]
#  [0.13910216 0.13752153 0.13421589 0.13357104 0.13309211]
#  [0.33648469 0.33393307 0.33326127 0.33621831 0.33393989]
#  [0.40848226 0.41738636 0.41652122 0.42134    0.39728389]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df22 = df22.drop(['地区'],axis=1)
normalized_data22 = preprocessing.normalize(df22, axis=0)
print(normalized_data22)
# Out:
# [[0.0057782  0.00533446 0.00509501 0.00486292 0.00481157]
#  [0.02011333 0.01476843 0.01492822 0.01477082 0.01478804]
#  [0.32810659 0.32703578 0.32489831 0.32226756 0.32143843]
#  [0.05956957 0.06115741 0.06296572 0.0645409  0.06567081]
#  [0.15077858 0.15548013 0.1604182  0.16411748 0.16830181]
#  [0.09587485 0.09521816 0.09766408 0.09998115 0.10133679]
#  [0.14216971 0.14709013 0.15159321 0.15765651 0.16472092]
#  [0.25163524 0.25822255 0.26384114 0.27409957 0.2744065 ]
#  [0.0052718  0.00398917 0.00406605 0.00413065 0.00407713]
#  [0.21603979 0.21294119 0.21209855 0.2109342  0.20438066]
#  [0.08969413 0.08527069 0.07916355 0.07335646 0.0704149 ]
#  [0.27323749 0.27770584 0.27593142 0.27508672 0.27489084]
#  [0.05334123 0.0521266  0.05135258 0.05098379 0.05043814]
#  [0.09996504 0.10108733 0.10251015 0.10482384 0.10700587]
#  [0.4390567  0.44200034 0.4431084  0.44359781 0.44408191]
#  [0.43448175 0.43305865 0.42971532 0.4233289  0.42280698]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df31 = df31.drop(['地区'],axis=1)
normalized_data31 = preprocessing.normalize(df31, axis=0)
print(normalized_data31)
# Out:
# [[0.00896319 0.00453708 0.00608899 0.00619764 0.0065563 ]
#  [0.00375854 0.00286037 0.00269683 0.00289363 0.00300732]
#  [0.38541309 0.2745459  0.30664124 0.32582108 0.29213164]
#  [0.26858388 0.33862362 0.35475488 0.36143307 0.32991028]
#  [0.1086595  0.09376627 0.09112005 0.09711746 0.10734061]
#  [0.06840574 0.06527092 0.06216594 0.06702956 0.07146828]
#  [0.04558866 0.03912213 0.05325373 0.06016273 0.06041539]
#  [0.05729349 0.05658896 0.06811406 0.07553395 0.08091962]
#  [0.00184262 0.00177341 0.00175419 0.00141793 0.00147364]
#  [0.1249892  0.09573433 0.07078389 0.06858837 0.05568643]
#  [0.06138099 0.07101946 0.06700943 0.07883915 0.07467589]
#  [0.25444917 0.23955081 0.23268118 0.24183774 0.21311257]
#  [0.16459077 0.16063255 0.15166015 0.16003769 0.15475197]
#  [0.19387844 0.18724451 0.19795855 0.20709677 0.2257485 ]
#  [0.082423   0.07817909 0.07066102 0.07447377 0.06823023]
#  [0.62170671 0.64998161 0.64338388 0.61835631 0.64674991]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df32 = df32.drop(['地区'],axis=1)
normalized_data32 = preprocessing.normalize(df32, axis=0)
print(normalized_data32)
# Out:
# [[0.20868041 0.21167567 0.20123315 0.19430559 0.1879428 ]
#  [0.2125759  0.20592742 0.19987116 0.19527936 0.1998478 ]
#  [0.19370996 0.19847247 0.19515887 0.19320626 0.19308634]
#  [0.19495561 0.19218373 0.18855171 0.18572653 0.18406558]
#  [0.15452859 0.15151342 0.15429208 0.15037022 0.15264429]
#  [0.14970453 0.14622156 0.14291908 0.14638639 0.14862224]
#  [0.12182461 0.12244138 0.12908019 0.15562015 0.1698498 ]
#  [0.17765239 0.18043799 0.17879678 0.17856295 0.17770038]
#  [0.21416127 0.20575024 0.20371203 0.19982527 0.19280964]
#  [0.21653933 0.21094939 0.2079915  0.2042711  0.201167  ]
#  [0.19484237 0.18298314 0.17820911 0.17771981 0.17381695]
#  [0.13840308 0.15126233 0.16193352 0.16586449 0.16631533]
#  [0.20430931 0.19961927 0.1960717  0.19448415 0.19037876]
#  [0.12880025 0.13319812 0.13406561 0.13868256 0.14055015]
#  [0.21058286 0.2066436  0.20102071 0.20018051 0.19593776]
#  [0.15629515 0.15065174 0.16301648 0.16813941 0.17152164]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df33 = df33.drop(['地区'],axis=1)
normalized_data33 = preprocessing.normalize(df33, axis=0)
print(normalized_data33)
# Out:
# [[0.2451549  0.24119637 0.26134586 0.24851566 0.26188692]
#  [0.16869782 0.16462305 0.1673887  0.15933704 0.16245231]
#  [0.15136255 0.14615813 0.1493329  0.14363396 0.14455051]
#  [0.14569114 0.16163119 0.15902758 0.15342252 0.1775634 ]
#  [0.14055476 0.13856939 0.13925046 0.13752357 0.136838  ]
#  [0.12257745 0.13256021 0.13123763 0.12002096 0.12016186]
#  [0.12150737 0.12620774 0.12309982 0.12059051 0.12314436]
#  [0.1246106  0.12230452 0.12333051 0.11973286 0.12023855]
#  [0.22888971 0.28683949 0.21530492 0.20086464 0.20492547]
#  [0.22546546 0.22047056 0.22095213 0.21446424 0.21284495]
#  [0.29726771 0.28823698 0.28021262 0.31343091 0.23995911]
#  [0.18036167 0.17511829 0.175861   0.16858427 0.16640387]
#  [0.21380161 0.19774687 0.21188892 0.19392277 0.18999909]
#  [0.20245878 0.20601974 0.20615428 0.19541619 0.19959626]
#  [0.17233608 0.16794865 0.16734405 0.16268913 0.15891374]
#  [0.16200983 0.16230525 0.15509418 0.15880502 0.15960823]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df41 = df41.drop(['地区'],axis=1)
normalized_data41 = preprocessing.normalize(df41, axis=0)
print(normalized_data41)
# Out:
# [[0.00674681 0.00723209 0.00877678 0.00980222 0.00948474]
#  [0.00207594 0.00154973 0.00175536 0.00196044 0.00203244]
#  [0.33630267 0.32544405 0.34814555 0.39404931 0.36109769]
#  [0.20707525 0.20611456 0.23580279 0.25224384 0.25608804]
#  [0.10587306 0.10693162 0.11994931 0.13461718 0.14227113]
#  [0.09912625 0.09918295 0.11000229 0.12154755 0.12601158]
#  [0.08148074 0.08213588 0.09303385 0.10455703 0.10636461]
#  [0.1691893  0.1678878  0.18314211 0.2078071  0.20663188]
#  [0.00103797 0.00103316 0.00117024 0.00130696 0.00135496]
#  [0.03269609 0.02376258 0.02223451 0.02352533 0.018292  ]
#  [0.10535408 0.10073268 0.11292789 0.12481496 0.13075395]
#  [0.10898698 0.11158082 0.12697073 0.1444194  0.13481884]
#  [0.13026538 0.1306942  0.14276893 0.15748903 0.14430358]
#  [0.28336614 0.27895204 0.31362356 0.34177079 0.34754805]
#  [0.03425305 0.03461072 0.03803271 0.04247629 0.03726149]
#  [0.29322686 0.29083333 0.31947474 0.36398916 0.37938969]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df42 = df42.drop(['地区'],axis=1)
normalized_data42 = preprocessing.normalize(df42, axis=0)
print(normalized_data42)
# Out:
# [[5.84097264e-03 6.45748585e-03 7.94158878e-03 8.93919758e-03
#   9.36883711e-03]
#  [5.30997513e-04 1.07624764e-03 1.22178289e-03 0.00000000e+00
#   0.00000000e+00]
#  [2.71339729e-01 2.65833167e-01 2.77955607e-01 3.18372960e-01
#   2.93316669e-01]
#  [1.64609229e-01 1.68970880e-01 1.89376348e-01 2.02163391e-01
#   1.86656062e-01]
#  [1.03013518e-01 1.06548516e-01 1.22789180e-01 1.35463225e-01
#   1.44135955e-01]
#  [8.70835921e-02 8.44854398e-02 9.65208483e-02 1.07958002e-01
#   1.11705366e-01]
#  [3.77008234e-02 4.41261533e-02 5.37584471e-02 6.25743831e-02
#   6.55818598e-02]
#  [1.31687383e-01 1.33454707e-01 1.48446621e-01 1.63656079e-01
#   1.65756349e-01]
#  [5.30997513e-04 5.38123820e-04 1.22178289e-03 1.37526117e-03
#   1.44135955e-03]
#  [3.29218458e-02 2.42155719e-02 2.32138749e-02 2.40670704e-02
#   1.87376742e-02]
#  [1.14695463e-01 1.12467878e-01 1.26454529e-01 1.40964270e-01
#   1.49180714e-01]
#  [1.17350450e-01 1.18925364e-01 1.36839684e-01 1.54716881e-01
# ...

# %%
import numpy as np
from sklearn import preprocessing
df43 = df43.drop(['地区'],axis=1)
normalized_data43 = preprocessing.normalize(df43, axis=0)
print(normalized_data43)
# Out:
# [[0.02049636 0.01950546 0.01956398 0.01923142 0.01980995]
#  [0.01688297 0.01685989 0.01698005 0.01552292 0.01562866]
#  [0.28355088 0.28642383 0.28424612 0.28842726 0.28809952]
#  [0.11133843 0.11181635 0.10910054 0.11487546 0.11736846]
#  [0.06651706 0.06887444 0.06805311 0.07132627 0.0727778 ]
#  [0.13992262 0.13487912 0.13152898 0.13165897 0.13190063]
#  [0.08415346 0.08274499 0.08296602 0.08346317 0.08327488]
#  [0.09221054 0.09026319 0.08704124 0.08916517 0.08910822]
#  [0.01735963 0.01768196 0.01754113 0.01782424 0.01798246]
#  [0.18249907 0.18094489 0.18463964 0.18552746 0.18634509]
#  [0.15290006 0.15411554 0.16351054 0.16081392 0.1572369 ]
#  [0.18568193 0.18179685 0.1839752  0.18555677 0.18912287]
#  [0.12540757 0.12626982 0.12653832 0.12617685 0.12681291]
#  [0.18494387 0.17330712 0.17473215 0.18521964 0.18739773]
#  [0.33842822 0.32897711 0.32473247 0.3244715  0.32606737]
#  [0.42476509 0.42074992 0.41545026 0.4436711  0.44666682]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df51 = df51.drop(['地区'],axis=1)
normalized_data51 = preprocessing.normalize(df51, axis=0)
print(normalized_data51)
# Out:
# [[0.01297215 0.01208334 0.01054762 0.00888101 0.00852244]
#  [0.01607738 0.01589806 0.01551627 0.0160627  0.01610568]
#  [0.22609317 0.23234372 0.22695917 0.22733574 0.22195353]
#  [0.05969375 0.05946403 0.06090062 0.06526904 0.06748384]
#  [0.11838187 0.12153771 0.11892938 0.11707833 0.12064555]
#  [0.16206135 0.16536831 0.16355738 0.15451075 0.15582948]
#  [0.08685825 0.08892735 0.09146138 0.10034129 0.09399354]
#  [0.23506385 0.22897683 0.22203545 0.21707234 0.20428566]
#  [0.01231155 0.01179021 0.01066369 0.00943397 0.00850347]
#  [0.3013173  0.29282148 0.28094037 0.26813648 0.26183034]
#  [0.13015904 0.12854018 0.12562788 0.11790439 0.11318564]
#  [0.19767058 0.19023524 0.19328317 0.19154195 0.18987499]
#  [0.16608385 0.17219165 0.17360701 0.16524957 0.1644721 ]
#  [0.12913238 0.12818599 0.13034941 0.1288219  0.12643259]
#  [0.38459486 0.3825875  0.36213496 0.34359475 0.36265449]
#  [0.31820255 0.31584008 0.31982841 0.33569489 0.33208121]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df52 = df52.drop(['地区'],axis=1)
normalized_data52 = preprocessing.normalize(df52, axis=0)
print(normalized_data52)
# Out:
# [[0.29462561 0.29608637 0.29556926 0.2891031  0.28917265]
#  [0.26440947 0.25780416 0.25343266 0.24654278 0.24273554]
#  [0.1565624  0.15682854 0.15707226 0.15802499 0.15784973]
#  [0.13112298 0.13133314 0.13182504 0.13317974 0.13292061]
#  [0.1529525  0.15428011 0.15615269 0.15898464 0.15922166]
#  [0.16708821 0.16381434 0.16458206 0.16745831 0.16686277]
#  [0.15740106 0.15366536 0.15260725 0.1541864  0.15318692]
#  [0.15393702 0.15429129 0.15307725 0.15515565 0.15533164]
#  [0.33819957 0.33951014 0.33916696 0.33502219 0.33448097]
#  [0.23285633 0.23299058 0.23167979 0.23221526 0.23262843]
#  [0.30332825 0.30516233 0.30525537 0.30641513 0.30605256]
#  [0.15506739 0.15643733 0.15751161 0.15949325 0.15952557]
#  [0.19854412 0.19919046 0.1999343  0.20037419 0.20169929]
#  [0.16095018 0.16162359 0.16139422 0.16295757 0.16223469]
#  [0.18375206 0.18215627 0.18161448 0.17996251 0.18055599]
#  [0.15459336 0.15459308 0.15493682 0.15457986 0.15224046]
# ...

# %%
import numpy as np
from sklearn import preprocessing
df53 = df53.drop(['地区'],axis=1)
normalized_data53 = preprocessing.normalize(df53, axis=0)
print(normalized_data53)
# Out:
# [[0.28790357 0.28288707 0.28001776 0.26406812 0.25527053]
#  [0.25080212 0.23621315 0.22834226 0.21268892 0.20883802]
#  [0.16126273 0.15945053 0.15832822 0.15965559 0.1666611 ]
#  [0.12893672 0.12847934 0.12449215 0.12993167 0.12355293]
#  [0.18648682 0.17735247 0.17680752 0.17165122 0.16990964]
#  [0.16510451 0.16045909 0.15395154 0.1554508  0.15816074]
#  [0.15732912 0.1516482  0.14661869 0.14980654 0.14522071]
#  [0.16107906 0.1599268  0.15990229 0.15606952 0.16486357]
#  [0.27688334 0.27966528 0.28728663 0.27899321 0.29458873]
#  [0.23895537 0.23206685 0.226717   0.21493652 0.22880573]
#  [0.27692925 0.27605127 0.27324799 0.27217464 0.27520576]
#  [0.16998708 0.17857115 0.18614955 0.18970781 0.18584916]
#  [0.21432821 0.20931822 0.20835287 0.20631229 0.20888133]
#  [0.15106902 0.15247466 0.15992788 0.17146182 0.16960645]
#  [0.15829339 0.15786765 0.15752199 0.15985762 0.1548364 ]
#  [0.14099775 0.14556883 0.14775765 0.15406183 0.15238917]
# ...

# %%
for col in df11.columns:
    p = df11[col].value_counts()

# %%
p
# Out:
# 2559     1
# 22961    1
# 2159     1
# 4472     1
# 16301    1
# 22394    1
# 5258     1
# 13588    1
# 20105    1
# 50309    1
# 9495     1
# 2737     1
# 19088    1
# 25448    1
# 37078    1
# 58488    1
# 2214     1
# 52940    1
# 27189    1
# 16847    1
# 15630    1
# 11221    1
# 14936    1
# 1147     1
# 10128    1
# 9463     1
# 16235    1
# 12965    1
# 26355    1
# 59967    1
# 9615     1
# Name: 2021, dtype: int64

# %%
data1 = pd.DataFrame({
    '2017各地村卫生室个数':df11.iloc[:,0],
    '2017农村居民教育文化支出占比%': df12.iloc[:,0],
    '2017主要农作物粮食产量（万吨）': df21.iloc[:,0],
    '2017农业机械总动力（万千瓦）':df22.iloc[:,0],
    '2017绿化覆盖面积（公顷）':df31.iloc[:,0],
    '2017供水普及率%': df32.iloc[:,0],
    '2017农村人均住宅建筑面积 ':df33.iloc[:,0],
    '2017 设有村镇建设管理机构的个数':df41.iloc[:,0],
    '2017有总体规划的乡个数':df42.iloc[:,0],
    '2017 1000人以上行政村个数':df43.iloc[:,0],
    '2017农、林、牧、渔业总产值（亿元）':df51.iloc[:,0],
    '2017农村居民人均可支配收入(元)':df52.iloc[:,0],
    '2017农村居民人均消费支出(元)':df53.iloc[:,0]
})

# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm1 = (data1 - data1.min()) / (data1.max() - data1.min())

# 计算每个指标的信息熵
p = data_norm1 / data_norm1.sum()
E = -(p * np.log(p)).sum()

# 计算每个指标的权重
w = (1 - E) / (13 - E.sum())

# 对每个样本进行加权求和，得到综合评价结果（采用加权平均法）
data1['加权平均综合评价'] = (data_norm1 * w).sum(axis=1)

# 输出结果
print(data1)
# Out:
#     2017各地村卫生室个数  2017农村居民教育文化支出占比%  2017主要农作物粮食产量（万吨）  2017农业机械总动力（万千瓦）  \
# 0           2696                9.1              41.12             133.5
# 1           2541                9.5             212.27             464.7
# 2          60225               11.1            3829.25            7580.6
# 3          28942               16.3            1355.10            1376.3
# 4          13625               15.6            3254.54            3483.6
# 5          19519               14.0            2330.74            2215.1
# 6          10108               15.2            4154.00            3284.7
# 7          10842               14.6            7410.34            5813.8
# 8           1187                8.5              99.78             121.8
# 9          15319               11.1            3610.80            4991.4
# 10         11535               11.0             580.14            2072.3
# 11         15331               12.0            4019.71            6312.9
# ...

# %%
w
# Out:
# 2017各地村卫生室个数           0.075309
# 2017农村居民教育文化支出占比%      0.085461
# 2017主要农作物粮食产量（万吨）      0.073273
# 2017农业机械总动力（万千瓦）       0.075287
# 2017绿化覆盖面积（公顷）         0.068537
# 2017供水普及率%             0.083060
# 2017农村人均住宅建筑面积         0.078598
# 2017 设有村镇建设管理机构的个数     0.072732
# 2017有总体规划的乡个数          0.073221
# 2017 1000人以上行政村个数      0.077147
# 2017农、林、牧、渔业总产值（亿元）    0.077825
# 2017农村居民人均可支配收入(元)     0.078530
# 2017农村居民人均消费支出(元)      0.081020
# dtype: float64

# %%
df1 = (data_norm1 * w).iloc[:,0] + (data_norm1 * w).iloc[:,1]
df2 = (data_norm1 * w).iloc[:,2] + (data_norm1 * w).iloc[:,3]
df3 = (data_norm1 * w).iloc[:,4] + (data_norm1 * w).iloc[:,5] + (data_norm1 * w).iloc[:,6]
df4 = (data_norm1 * w).iloc[:,7] + (data_norm1 * w).iloc[:,8] + (data_norm1 * w).iloc[:,9]
df5 = (data_norm1 * w).iloc[:,10] + (data_norm1 * w).iloc[:,11] + (data_norm1 * w).iloc[:,12]

# %%
df1.to_excel('2017一级_乡风文化加权法评分.xlsx', index=False)
df2.to_excel('2017一级_产业兴旺加权法评分.xlsx', index=False)
df3.to_excel('2017一级_生态宜居加权法评分.xlsx', index=False)
df4.to_excel('2017一级_治理有效加权法评分.xlsx', index=False)
df5.to_excel('2017一级_生活富裕加权法评分.xlsx', index=False)

# %%
data1.to_excel('2017熵权法.xlsx', index=False)

# %%
normalized_data11[:,0]
# Out:
# array([0.01835263, 0.01729749, 0.40997307, 0.19701853, 0.09275024,
#        0.1328728 , 0.06880876, 0.07380536, 0.00808033, 0.1042819 ,
#        0.07852286, 0.10436359, 0.1266713 , 0.20240995, 0.3609533 ,
#        0.38435699, 0.16770605, 0.28688925, 0.18011586, 0.1413888 ,
#        0.01795781, 0.07481966, 0.38268238, 0.13984353, 0.09153172,
#        0.03624237, 0.17003416, 0.1159429 , 0.03075564, 0.01566373,
#        0.07054464])

# %%
# data.to_excel('sample_data.xlsx', sheet_name='sheet1', index=False)

# %%
data2 = pd.DataFrame({
    '2018各地村卫生室个数':df11.iloc[:,1],
    '2018农村居民教育文化支出占比%': df12.iloc[:,1],
    '2018主要农作物粮食产量（万吨）': df21.iloc[:,1],
    '2018农业机械总动力（万千瓦）':df22.iloc[:,1],
    '2018绿化覆盖面积（公顷）':df31.iloc[:,1],
    '2018供水普及率%': df32.iloc[:,1],
    '2018农村人均住宅建筑面积 ':df33.iloc[:,1],
    '2018 设有村镇建设管理机构的个数':df41.iloc[:,1],
    '2018有总体规划的乡个数':df42.iloc[:,1],
    '2018 1000人以上行政村个数':df43.iloc[:,1],
    '2018农、林、牧、渔业总产值（亿元）':df51.iloc[:,1],
    '2018农村居民人均可支配收入(元)':df52.iloc[:,1],
    '2018农村居民人均消费支出(元)':df53.iloc[:,1]
})

# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm2 = (data2 - data2.min()) / (data2.max() - data2.min())

# 计算每个指标的信息熵
p = data_norm2 / data_norm2.sum()
E = -(p * np.log(p)).sum()

# 计算每个指标的权重
w = (1 - E) / (13 - E.sum())

# 对每个样本进行加权求和，得到综合评价结果（采用加权平均法）
data2['加权平均综合评价'] = (data_norm2 * w).sum(axis=1)

# 输出结果
print(data2)
# Out:
#     2018各地村卫生室个数  2018农村居民教育文化支出占比%  2018主要农作物粮食产量（万吨）  2018农业机械总动力（万千瓦）  \
# 0           2493                7.1              34.14             125.7
# 1           2511                7.3             209.69             348.0
# 2          59047               10.3            3700.86            7706.2
# 3          28338               12.5            1380.40            1441.1
# 4          13539               13.7            3553.28            3663.7
# 5          19127               11.6            2192.45            2243.7
# 6           9901               13.0            3632.74            3466.0
# 7          10740               12.4            7506.80            6084.7
# 8           1162                5.9             103.74              94.0
# 9          15311                9.3            3660.28            5017.7
# 10         11483                9.1             599.14            2009.3
# 11         15317               10.0            4007.25            6543.8
# ...

# %%
df1 = (data_norm2 * w).iloc[:,0] + (data_norm2 * w).iloc[:,1]
df2 = (data_norm2 * w).iloc[:,2] + (data_norm2 * w).iloc[:,3]
df3 = (data_norm2 * w).iloc[:,4] + (data_norm2 * w).iloc[:,5] + (data_norm2 * w).iloc[:,6]
df4 = (data_norm2 * w).iloc[:,7] + (data_norm2 * w).iloc[:,8] + (data_norm2 * w).iloc[:,9]
df5 = (data_norm2 * w).iloc[:,10] + (data_norm2 * w).iloc[:,11] + (data_norm2 * w).iloc[:,12]

df1.to_excel('2018一级_乡风文化加权法评分.xlsx', index=False)
df2.to_excel('2018一级_产业兴旺加权法评分.xlsx', index=False)
df3.to_excel('2018一级_生态宜居加权法评分.xlsx', index=False)
df4.to_excel('2018一级_治理有效加权法评分.xlsx', index=False)
df5.to_excel('2018一级_生活富裕加权法评分.xlsx', index=False)

# %%
data2.to_excel('2018熵权法.xlsx', index=False)

# %%
data3 = pd.DataFrame({
    '2019各地村卫生室个数':df11.iloc[:,2],
    '2019农村居民教育文化支出占比%': df12.iloc[:,2],
    '2019主要农作物粮食产量（万吨）': df21.iloc[:,2],
    '2019农业机械总动力（万千瓦）':df22.iloc[:,2],
    '2019绿化覆盖面积（公顷）':df31.iloc[:,2],
    '2019供水普及率%': df32.iloc[:,2],
    '2019农村人均住宅建筑面积 ':df33.iloc[:,2],
    '2019 设有村镇建设管理机构的个数':df41.iloc[:,2],
    '2019有总体规划的乡个数':df42.iloc[:,2],
    '2019 1000人以上行政村个数':df43.iloc[:,2],
    '2019农、林、牧、渔业总产值（亿元）':df51.iloc[:,2],
    '2019农村居民人均可支配收入(元)':df52.iloc[:,2],
    '2019农村居民人均消费支出(元)':df53.iloc[:,2]
})

# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm3 = (data3 - data3.min()) / (data3.max() - data3.min())

# 计算每个指标的信息熵
p = data_norm3 / data_norm3.sum()
E = -(p * np.log(p)).sum()

# 计算每个指标的权重
w = (1 - E) / (13 - E.sum())

# 对每个样本进行加权求和，得到综合评价结果（采用加权平均法）
data3['加权平均综合评价'] = (data_norm3 * w).sum(axis=1)

# 输出结果
print(data3)
# Out:
#     2019各地村卫生室个数  2019农村居民教育文化支出占比%  2019主要农作物粮食产量（万吨）  2019农业机械总动力（万千瓦）  \
# 0           2449                9.2              28.76             122.8
# 1           2374                8.9             223.25             359.8
# 2          59526               12.7            3739.24            7830.7
# 3          28106               14.7            1361.80            1517.6
# 4          13321               15.0            3652.54            3866.4
# 5          17963               13.9            2429.95            2353.9
# 6           9615               15.8            3877.93            3653.7
# 7          10448               16.1            7503.01            6359.1
# 8           1179                7.9              95.89              98.0
# 9          15169               11.4            3706.20            5112.0
# 10         11590               13.3             592.15            1908.0
# 11         15549               12.5            4054.00            6650.5
# ...

# %%
df1 = (data_norm3 * w).iloc[:,0] + (data_norm3 * w).iloc[:,1]
df2 = (data_norm3 * w).iloc[:,2] + (data_norm3 * w).iloc[:,3]
df3 = (data_norm3 * w).iloc[:,4] + (data_norm3 * w).iloc[:,5] + (data_norm3 * w).iloc[:,6]
df4 = (data_norm3 * w).iloc[:,7] + (data_norm3 * w).iloc[:,8] + (data_norm3 * w).iloc[:,9]
df5 = (data_norm3 * w).iloc[:,10] + (data_norm3 * w).iloc[:,11] + (data_norm3 * w).iloc[:,12]

df1.to_excel('2019一级_乡风文化加权法评分.xlsx', index=False)
df2.to_excel('2019一级_产业兴旺加权法评分.xlsx', index=False)
df3.to_excel('2019一级_生态宜居加权法评分.xlsx', index=False)
df4.to_excel('2019一级_治理有效加权法评分.xlsx', index=False)
df5.to_excel('2019一级_生活富裕加权法评分.xlsx', index=False)

# %%
data3.to_excel('2019熵权法.xlsx', index=False)

# %%
data4 = pd.DataFrame({
    '2020各地村卫生室个数':df11.iloc[:,3],
    '2020农村居民教育文化支出占比%': df12.iloc[:,3],
    '2020主要农作物粮食产量（万吨）': df21.iloc[:,3],
    '2020农业机械总动力（万千瓦）':df22.iloc[:,3],
    '2020绿化覆盖面积（公顷）':df31.iloc[:,3],
    '2020供水普及率%': df32.iloc[:,3],
    '2020农村人均住宅建筑面积 ':df33.iloc[:,3],
    '2020 设有村镇建设管理机构的个数':df41.iloc[:,3],
    '2020有总体规划的乡个数':df42.iloc[:,3],
    '2020 1000人以上行政村个数':df43.iloc[:,3],
    '2020农、林、牧、渔业总产值（亿元）':df51.iloc[:,3],
    '2020农村居民人均可支配收入(元)':df52.iloc[:,3],
    '2020农村居民人均消费支出(元)':df53.iloc[:,3]
})

# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm4 = (data4 - data4.min()) / (data4.max() - data4.min())

# 计算每个指标的信息熵
p = data_norm4 / data_norm4.sum()
E = -(p * np.log(p)).sum()

# 计算每个指标的权重
w = (1 - E) / (13 - E.sum())

# 对每个样本进行加权求和，得到综合评价结果（采用加权平均法）
data4['加权平均综合评价'] = (data_norm4 * w).sum(axis=1)

# 输出结果
print(data4)
# Out:
#     2020各地村卫生室个数  2020农村居民教育文化支出占比%  2020主要农作物粮食产量（万吨）  2020农业机械总动力（万千瓦）  \
# 0           2472                7.1              30.53             120.2
# 1           2196                6.5             228.18             365.1
# 2          60183               10.5            3795.89            7965.7
# 3          26800               11.2            1424.27            1595.3
# 4          13030               12.5            3664.10            4056.6
# 5          17567               10.6            2338.83            2471.3
# 6           9638               11.8            3803.17            3896.9
# 7          10385               11.1            7540.78            6775.1
# 8           1169                5.4              91.44             102.1
# 9          15020               10.4            3729.06            5213.8
# 10         11300               10.4             605.70            1813.2
# 11         15710               11.6            4019.22            6799.5
# ...

# %%
df1 = (data_norm4 * w).iloc[:,0] + (data_norm4 * w).iloc[:,1]
df2 = (data_norm4 * w).iloc[:,2] + (data_norm4 * w).iloc[:,3]
df3 = (data_norm4 * w).iloc[:,4] + (data_norm4 * w).iloc[:,5] + (data_norm4 * w).iloc[:,6]
df4 = (data_norm4 * w).iloc[:,7] + (data_norm4 * w).iloc[:,8] + (data_norm4 * w).iloc[:,9]
df5 = (data_norm4 * w).iloc[:,10] + (data_norm4 * w).iloc[:,11] + (data_norm4 * w).iloc[:,12]

df1.to_excel('2020一级_乡风文化加权法评分.xlsx', index=False)
df2.to_excel('2020一级_产业兴旺加权法评分.xlsx', index=False)
df3.to_excel('2020一级_生态宜居加权法评分.xlsx', index=False)
df4.to_excel('2020一级_治理有效加权法评分.xlsx', index=False)
df5.to_excel('2020一级_生活富裕加权法评分.xlsx', index=False)

# %%
data4.to_excel('2020熵权法.xlsx', index=False)

# %%
data5 = pd.DataFrame({
    '2021各地村卫生室个数':df11.iloc[:,4],
    '2021农村居民教育文化支出占比%': df12.iloc[:,4],
    '2021主要农作物粮食产量（万吨）': df21.iloc[:,4],
    '2021农业机械总动力（万千瓦）':df22.iloc[:,4],
    '2021绿化覆盖面积（公顷）':df31.iloc[:,4],
    '2021供水普及率%': df32.iloc[:,4],
    '2021农村人均住宅建筑面积 ':df33.iloc[:,4],
    '2021 设有村镇建设管理机构的个数':df41.iloc[:,4],
    '2021有总体规划的乡个数':df42.iloc[:,4],
    '2021 1000人以上行政村个数':df43.iloc[:,4],
    '2021农、林、牧、渔业总产值（亿元）':df51.iloc[:,4],
    '2021农村居民人均可支配收入(元)':df52.iloc[:,4],
    '2021农村居民人均消费支出(元)':df53.iloc[:,4]
})

# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm5 = (data5 - data5.min()) / (data5.max() - data5.min())

# 计算每个指标的信息熵
p = data_norm5 / data_norm5.sum()
E = -(p * np.log(p)).sum()

# 计算每个指标的权重
w = (1 - E) / (13 - E.sum())

# 对每个样本进行加权求和，得到综合评价结果（采用加权平均法）
data5['加权平均综合评价'] = (data_norm5 * w).sum(axis=1)

# 输出结果
print(data5)
# Out:
#     2021各地村卫生室个数  2021农村居民教育文化支出占比%  2021主要农作物粮食产量（万吨）  2021农业机械总动力（万千瓦）  \
# 0           2559                7.3              37.75             121.2
# 1           2214                8.6             249.87             372.5
# 2          59967               11.5            3825.09            8096.8
# 3          26355               11.7            1421.25            1654.2
# 4          12965               12.7            3840.30            4239.4
# 5          16235               13.0            2538.74            2552.6
# 6           9463               14.7            4039.24            4149.2
# 7          10128               11.9            7867.72            6912.1
# 8           1147                5.7              93.96             102.7
# 9          14936               10.7            3746.10            5148.2
# 10         11221               11.4             620.90            1773.7
# 11         15630               14.1            4087.56            6924.3
# ...

# %%
df1 = (data_norm5 * w).iloc[:,0] + (data_norm5 * w).iloc[:,1]
df2 = (data_norm5 * w).iloc[:,2] + (data_norm5 * w).iloc[:,3]
df3 = (data_norm5 * w).iloc[:,4] + (data_norm5 * w).iloc[:,5] + (data_norm5 * w).iloc[:,6]
df4 = (data_norm5 * w).iloc[:,7] + (data_norm5 * w).iloc[:,8] + (data_norm5 * w).iloc[:,9]
df5 = (data_norm5 * w).iloc[:,10] + (data_norm5 * w).iloc[:,11] + (data_norm5 * w).iloc[:,12]

df1.to_excel('2021一级_乡风文化加权法评分.xlsx', index=False)
df2.to_excel('2021一级_产业兴旺加权法评分.xlsx', index=False)
df3.to_excel('2021一级_生态宜居加权法评分.xlsx', index=False)
df4.to_excel('2021一级_治理有效加权法评分.xlsx', index=False)
df5.to_excel('2021一级_生活富裕加权法评分.xlsx', index=False)

# %%
data5.to_excel('2021熵权法.xlsx',index=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,10))
plt.xlabel('City', fontsize=18)
plt.ylabel('score', fontsize=18)
plt.plot(data1.index.values,data1.iloc[:,-1],label='2017',)
plt.plot(data2.index.values,data2.iloc[:,-1],label='2018',)
plt.plot(data3.index.values,data3.iloc[:,-1],label='2019',)
plt.plot(data4.index.values,data4.iloc[:,-1],label='2020',)
plt.plot(data5.index.values,data5.iloc[:,-1],label='2021',)
plt.legend()
plt.show()

# %% [markdown]
# # 一级指标

# %%
data1.iloc[:,0]
# Out:
# 0      2696
# 1      2541
# 2     60225
# 3     28942
# 4     13625
# 5     19519
# 6     10108
# 7     10842
# 8      1187
# 9     15319
# 10    11535
# 11    15331
# 12    18608
# 13    29734
# 14    53024
# 15    56462
# 16    24636
# 17    42144
# 18    26459
# 19    20770
# 20     2638
# 21    10991
# 22    56216
# 23    20543
# 24    13446
# 25     5324
# 26    24978
# 27    17032
# 28     4518
# 29     2301
# 30    10363
# Name: 2017各地村卫生室个数, dtype: int64

# %%
data1 = pd.DataFrame({
    '2017各地村卫生室个数':df11.iloc[:,0],
    '2017农村居民教育文化支出占比%': df12.iloc[:,0],
    '2017主要农作物粮食产量（万吨）': df21.iloc[:,0],
    '2017农业机械总动力（万千瓦）':df22.iloc[:,0],
    '2017绿化覆盖面积（公顷）':df31.iloc[:,0],
    '2017供水普及率%': df32.iloc[:,0],
    '2017农村人均住宅建筑面积 ':df33.iloc[:,0],
    '2017 设有村镇建设管理机构的个数':df41.iloc[:,0],
    '2017有总体规划的乡个数':df42.iloc[:,0],
    '2017 1000人以上行政村个数':df43.iloc[:,0],
    '2017农、林、牧、渔业总产值（亿元）':df51.iloc[:,0],
    '2017农村居民人均可支配收入(元)':df52.iloc[:,0],
    '2017农村居民人均消费支出(元)':df53.iloc[:,0]
})

data_norm1 = (data1 - data1.min()) / (data1.max() - data1.min())
p = data_norm1 / data_norm1.sum()
E = -(p * np.log(p)).sum()
data_weighted = data_norm1 * p
ideal_positive = data_weighted.max(axis=0)
ideal_negative = data_weighted.min(axis=0)
distance_positive = np.sqrt(np.sum((data_weighted - ideal_positive)**2, axis=1))
distance_negative = np.sqrt(np.sum((data_weighted - ideal_negative)**2, axis=1))
score = distance_negative / (distance_negative + distance_positive)
data1['TOSIS综合评价(未排序)'] = score
print(data1)
# Out:
#     2017各地村卫生室个数  2017农村居民教育文化支出占比%  2017主要农作物粮食产量（万吨）  2017农业机械总动力（万千瓦）  \
# 0           2696                9.1              41.12             133.5
# 1           2541                9.5             212.27             464.7
# 2          60225               11.1            3829.25            7580.6
# 3          28942               16.3            1355.10            1376.3
# 4          13625               15.6            3254.54            3483.6
# 5          19519               14.0            2330.74            2215.1
# 6          10108               15.2            4154.00            3284.7
# 7          10842               14.6            7410.34            5813.8
# 8           1187                8.5              99.78             121.8
# 9          15319               11.1            3610.80            4991.4
# 10         11535               11.0             580.14            2072.3
# 11         15331               12.0            4019.71            6312.9
# ...

# %%
data_norm1
# Out:
#     2017各地村卫生室个数  2017农村居民教育文化支出占比%  2017主要农作物粮食产量（万吨）  2017农业机械总动力（万千瓦）  \
# 0       0.025560           0.292857           0.000000          0.001167
# 1       0.022934           0.321429           0.023225          0.034214
# 2       1.000000           0.435714           0.514048          0.744228
# 3       0.470121           0.807143           0.178307          0.125172
# 4       0.210678           0.757143           0.436060          0.335435
# 5       0.310512           0.642857           0.310700          0.208866
# 6       0.151106           0.728571           0.558116          0.315589
# 7       0.163539           0.685714           1.000000          0.567939
# 8       0.000000           0.250000           0.007960          0.000000
# 9       0.239371           0.435714           0.484404          0.485881
# 10      0.175277           0.428571           0.073145          0.194618
# 11      0.239575           0.500000           0.539893          0.617739
# ...

# %%
data_weighted
# Out:
#     2017各地村卫生室个数  2017农村居民教育文化支出占比%  2017主要农作物粮食产量（万吨）  2017农业机械总动力（万千瓦）  \
# 0       0.000065           0.004824           0.000000      1.437641e-07
# 1       0.000052           0.005811           0.000061      1.234848e-04
# 2       0.099180           0.010678           0.030011      5.842739e-02
# 3       0.021920           0.036644           0.003611      1.652799e-03
# 4       0.004402           0.032245           0.021595      1.186922e-02
# 5       0.009563           0.023245           0.010964      4.601946e-03
# 6       0.002265           0.029857           0.035377      1.050629e-02
# 7       0.002653           0.026448           0.113572      3.402580e-02
# 8       0.000000           0.003515           0.000007      0.000000e+00
# 9       0.005683           0.010678           0.026649      2.490377e-02
# 10      0.003047           0.010331           0.000608      3.995494e-03
# 11      0.005693           0.014062           0.033104      4.025448e-02
# ...

# %%
data_weighted.to_excel('2017weight.xlsx',index=False)

# %%
data1.to_excel('2017TOPSIS.xlsx',index=False)

# %%
data2 = pd.DataFrame({
    '2018各地村卫生室个数':df11.iloc[:,1],
    '2018农村居民教育文化支出占比%': df12.iloc[:,1],
    '2018主要农作物粮食产量（万吨）': df21.iloc[:,1],
    '2018农业机械总动力（万千瓦）':df22.iloc[:,1],
    '2018绿化覆盖面积（公顷）':df31.iloc[:,1],
    '2018供水普及率%': df32.iloc[:,1],
    '2018农村人均住宅建筑面积 ':df33.iloc[:,1],
    '2018 设有村镇建设管理机构的个数':df41.iloc[:,1],
    '2018有总体规划的乡个数':df42.iloc[:,1],
    '2018 1000人以上行政村个数':df43.iloc[:,1],
    '2018农、林、牧、渔业总产值（亿元）':df51.iloc[:,1],
    '2018农村居民人均可支配收入(元)':df52.iloc[:,1],
    '2018农村居民人均消费支出(元)':df53.iloc[:,1]
})


# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm2 = (data2 - data2.min()) / (data2.max() - data2.min())

# 计算每个指标的信息熵
p = data_norm2 / data_norm2.sum()
E = -(p * np.log(p)).sum()

# 对归一化后的数据进行加权处理，得到加权归一化矩阵
data_weighted = data_norm2 * p

ideal_positive = data_weighted.max(axis=0)
ideal_negative = data_weighted.min(axis=0)

# 计算各评价对象到正负理想解的距离
distance_positive = np.sqrt(np.sum((data_weighted - ideal_positive)**2, axis=1))
distance_negative = np.sqrt(np.sum((data_weighted - ideal_negative)**2, axis=1))

# 计算各评价对象的综合得分
score = distance_negative / (distance_negative + distance_positive)


data2['TOSIS综合评价(未排序)'] = score
print(data2)
# # 对综合得分进行排序
# ranking = np.argsort(score)

# # 输出排序结果
# print(ranking)
# Out:
#     2018各地村卫生室个数  2018农村居民教育文化支出占比%  2018主要农作物粮食产量（万吨）  2018农业机械总动力（万千瓦）  \
# 0           2493                7.1              34.14             125.7
# 1           2511                7.3             209.69             348.0
# 2          59047               10.3            3700.86            7706.2
# 3          28338               12.5            1380.40            1441.1
# 4          13539               13.7            3553.28            3663.7
# 5          19127               11.6            2192.45            2243.7
# 6           9901               13.0            3632.74            3466.0
# 7          10740               12.4            7506.80            6084.7
# 8           1162                5.9             103.74              94.0
# 9          15311                9.3            3660.28            5017.7
# 10         11483                9.1             599.14            2009.3
# 11         15317               10.0            4007.25            6543.8
# ...

# %%
data_weighted.to_excel('2018weight.xlsx',index=False)

# %%
data2.to_excel('2018TOPSIS.xlsx',index=False)

# %%
data3 = pd.DataFrame({
    '2019各地村卫生室个数':df11.iloc[:,2],
    '2019农村居民教育文化支出占比%': df12.iloc[:,2],
    '2019主要农作物粮食产量（万吨）': df21.iloc[:,2],
    '2019农业机械总动力（万千瓦）':df22.iloc[:,2],
    '2019绿化覆盖面积（公顷）':df31.iloc[:,2],
    '2019供水普及率%': df32.iloc[:,2],
    '2019农村人均住宅建筑面积 ':df33.iloc[:,2],
    '2019 设有村镇建设管理机构的个数':df41.iloc[:,2],
    '2019有总体规划的乡个数':df42.iloc[:,2],
    '2019 1000人以上行政村个数':df43.iloc[:,2],
    '2019农、林、牧、渔业总产值（亿元）':df51.iloc[:,2],
    '2019农村居民人均可支配收入(元)':df52.iloc[:,2],
    '2019农村居民人均消费支出(元)':df53.iloc[:,2]
})



# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm3 = (data3 - data3.min()) / (data3.max() - data3.min())

# 计算每个指标的信息熵
p = data_norm3 / data_norm3.sum()
E = -(p * np.log(p)).sum()

# 对归一化后的数据进行加权处理，得到加权归一化矩阵
data_weighted = data_norm3 * p

ideal_positive = data_weighted.max(axis=0)
ideal_negative = data_weighted.min(axis=0)

# 计算各评价对象到正负理想解的距离
distance_positive = np.sqrt(np.sum((data_weighted - ideal_positive)**2, axis=1))
distance_negative = np.sqrt(np.sum((data_weighted - ideal_negative)**2, axis=1))

# 计算各评价对象的综合得分
score = distance_negative / (distance_negative + distance_positive)


data3['TOSIS综合评价(未排序)'] = score
print(data3)
# # 对综合得分进行排序
# ranking = np.argsort(score)

# # 输出排序结果
# print(ranking)
# Out:
#     2019各地村卫生室个数  2019农村居民教育文化支出占比%  2019主要农作物粮食产量（万吨）  2019农业机械总动力（万千瓦）  \
# 0           2449                9.2              28.76             122.8
# 1           2374                8.9             223.25             359.8
# 2          59526               12.7            3739.24            7830.7
# 3          28106               14.7            1361.80            1517.6
# 4          13321               15.0            3652.54            3866.4
# 5          17963               13.9            2429.95            2353.9
# 6           9615               15.8            3877.93            3653.7
# 7          10448               16.1            7503.01            6359.1
# 8           1179                7.9              95.89              98.0
# 9          15169               11.4            3706.20            5112.0
# 10         11590               13.3             592.15            1908.0
# 11         15549               12.5            4054.00            6650.5
# ...

# %%
data_weighted.to_excel('2019weight.xlsx',index=False)

# %%
data3.to_excel('2019TOPSIS.xlsx',index=False)

# %%
data4 = pd.DataFrame({
    '2020各地村卫生室个数':df11.iloc[:,3],
    '2020农村居民教育文化支出占比%': df12.iloc[:,3],
    '2020主要农作物粮食产量（万吨）': df21.iloc[:,3],
    '2020农业机械总动力（万千瓦）':df22.iloc[:,3],
    '2020绿化覆盖面积（公顷）':df31.iloc[:,3],
    '2020供水普及率%': df32.iloc[:,3],
    '2020农村人均住宅建筑面积 ':df33.iloc[:,3],
    '2020 设有村镇建设管理机构的个数':df41.iloc[:,3],
    '2020有总体规划的乡个数':df42.iloc[:,3],
    '2020 1000人以上行政村个数':df43.iloc[:,3],
    '2020农、林、牧、渔业总产值（亿元）':df51.iloc[:,3],
    '2020农村居民人均可支配收入(元)':df52.iloc[:,3],
    '2020农村居民人均消费支出(元)':df53.iloc[:,3]
})


# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm4 = (data4 - data4.min()) / (data4.max() - data4.min())

# 计算每个指标的信息熵
p = data_norm4 / data_norm4.sum()
E = -(p * np.log(p)).sum()

# 对归一化后的数据进行加权处理，得到加权归一化矩阵
data_weighted = data_norm4 * p

ideal_positive = data_weighted.max(axis=0)
ideal_negative = data_weighted.min(axis=0)

# 计算各评价对象到正负理想解的距离
distance_positive = np.sqrt(np.sum((data_weighted - ideal_positive)**2, axis=1))
distance_negative = np.sqrt(np.sum((data_weighted - ideal_negative)**2, axis=1))

# 计算各评价对象的综合得分
score = distance_negative / (distance_negative + distance_positive)


data4['TOSIS综合评价(未排序)'] = score
print(data4)
# # 对综合得分进行排序
# ranking = np.argsort(score)

# # 输出排序结果
# print(ranking)
# Out:
#     2020各地村卫生室个数  2020农村居民教育文化支出占比%  2020主要农作物粮食产量（万吨）  2020农业机械总动力（万千瓦）  \
# 0           2472                7.1              30.53             120.2
# 1           2196                6.5             228.18             365.1
# 2          60183               10.5            3795.89            7965.7
# 3          26800               11.2            1424.27            1595.3
# 4          13030               12.5            3664.10            4056.6
# 5          17567               10.6            2338.83            2471.3
# 6           9638               11.8            3803.17            3896.9
# 7          10385               11.1            7540.78            6775.1
# 8           1169                5.4              91.44             102.1
# 9          15020               10.4            3729.06            5213.8
# 10         11300               10.4             605.70            1813.2
# 11         15710               11.6            4019.22            6799.5
# ...

# %%
data_weighted.to_excel('2020weight.xlsx',index=False)

# %%
data4.to_excel('2020TOPSIS.xlsx',index=False)

# %%
data5 = pd.DataFrame({
    '2021各地村卫生室个数':df11.iloc[:,4],
    '2021农村居民教育文化支出占比%': df12.iloc[:,4],
    '2021主要农作物粮食产量（万吨）': df21.iloc[:,4],
    '2021农业机械总动力（万千瓦）':df22.iloc[:,4],
    '2021绿化覆盖面积（公顷）':df31.iloc[:,4],
    '2021供水普及率%': df32.iloc[:,4],
    '2021农村人均住宅建筑面积 ':df33.iloc[:,4],
    '2021 设有村镇建设管理机构的个数':df41.iloc[:,4],
    '2021有总体规划的乡个数':df42.iloc[:,4],
    '2021 1000人以上行政村个数':df43.iloc[:,4],
    '2021农、林、牧、渔业总产值（亿元）':df51.iloc[:,4],
    '2021农村居民人均可支配收入(元)':df52.iloc[:,4],
    '2021农村居民人均消费支出(元)':df53.iloc[:,4]
})

# 对数据进行正向化处理
# 将数据进行正向化处理
data_norm5 = (data5 - data5.min()) / (data5.max() - data5.min())

# 计算每个指标的信息熵
p = data_norm5 / data_norm5.sum()
E = -(p * np.log(p)).sum()

# 对归一化后的数据进行加权处理，得到加权归一化矩阵
data_weighted = data_norm5 * p

ideal_positive = data_weighted.max(axis=0)
ideal_negative = data_weighted.min(axis=0)

# 计算各评价对象到正负理想解的距离
distance_positive = np.sqrt(np.sum((data_weighted - ideal_positive)**2, axis=1))
distance_negative = np.sqrt(np.sum((data_weighted - ideal_negative)**2, axis=1))

# 计算各评价对象的综合得分
score = distance_negative / (distance_negative + distance_positive)


data5['TOSIS综合评价(未排序)'] = score
print(data5)
# # 对综合得分进行排序
# ranking = np.argsort(score)

# # 输出排序结果
# print(ranking)
# Out:
#     2021各地村卫生室个数  2021农村居民教育文化支出占比%  2021主要农作物粮食产量（万吨）  2021农业机械总动力（万千瓦）  \
# 0           2559                7.3              37.75             121.2
# 1           2214                8.6             249.87             372.5
# 2          59967               11.5            3825.09            8096.8
# 3          26355               11.7            1421.25            1654.2
# 4          12965               12.7            3840.30            4239.4
# 5          16235               13.0            2538.74            2552.6
# 6           9463               14.7            4039.24            4149.2
# 7          10128               11.9            7867.72            6912.1
# 8           1147                5.7              93.96             102.7
# 9          14936               10.7            3746.10            5148.2
# 10         11221               11.4             620.90            1773.7
# 11         15630               14.1            4087.56            6924.3
# ...

# %%
data_weighted.to_excel('2021weight.xlsx',index=False)

# %%
data5.to_excel('2021TOPSIS.xlsx',index=False)

# %%
data1 = pd.DataFrame({
    '2017各地村卫生室个数':df11.iloc[:,0],
    '2017农村居民教育文化支出占比%': df12.iloc[:,0],
    '2017主要农作物粮食产量（万吨）': df21.iloc[:,0],
    '2017农业机械总动力（万千瓦）':df22.iloc[:,0],
    '2017绿化覆盖面积（公顷）':df31.iloc[:,0],
    '2017供水普及率%': df32.iloc[:,0],
    '2017农村人均住宅建筑面积 ':df33.iloc[:,0],
    '2017 设有村镇建设管理机构的个数':df41.iloc[:,0],
    '2017有总体规划的乡个数':df42.iloc[:,0],
    '2017 1000人以上行政村个数':df43.iloc[:,0],
    '2017农、林、牧、渔业总产值（亿元）':df51.iloc[:,0],
    '2017农村居民人均可支配收入(元)':df52.iloc[:,0],
    '2017农村居民人均消费支出(元)':df53.iloc[:,0]
})
data_norm1 = (data1 - data1.min()) / (data1.max() - data1.min())
p = data_norm1.apply(lambda x: x / x.sum(), axis=0)
w = -np.sum(p * np.log(p)) / np.log(data_norm1.shape[1])
weights = (1 - w) / (1 - p.apply(lambda x: np.sum((x / x.sum()) * np.log(x / x.sum())), axis=0))
data_weighted = data_norm1 * weights
z_plus = data_weighted.max(axis=0)
z_minus = data_weighted.min(axis=0)
d_plus = np.sqrt(np.sum((data_weighted - z_plus) ** 2, axis=1))
d_minus = np.sqrt(np.sum((data_weighted - z_minus) ** 2, axis=1))
scores = d_minus / (d_plus + d_minus)
data1['TOSIS综合评价(未排序)'] = scores
print(data1)
# Out:
#     2017各地村卫生室个数  2017农村居民教育文化支出占比%  2017主要农作物粮食产量（万吨）  2017农业机械总动力（万千瓦）  \
# 0           2696                9.1              41.12             133.5
# 1           2541                9.5             212.27             464.7
# 2          60225               11.1            3829.25            7580.6
# 3          28942               16.3            1355.10            1376.3
# 4          13625               15.6            3254.54            3483.6
# 5          19519               14.0            2330.74            2215.1
# 6          10108               15.2            4154.00            3284.7
# 7          10842               14.6            7410.34            5813.8
# 8           1187                8.5              99.78             121.8
# 9          15319               11.1            3610.80            4991.4
# 10         11535               11.0             580.14            2072.3
# 11         15331               12.0            4019.71            6312.9
# ...

# %%
data1.to_excel('2017TOPSIS.xlsx',index=False)

# %%
data2 = pd.DataFrame({
    '2018各地村卫生室个数':df11.iloc[:,1],
    '2018农村居民教育文化支出占比%': df12.iloc[:,1],
    '2018主要农作物粮食产量（万吨）': df21.iloc[:,1],
    '2018农业机械总动力（万千瓦）':df22.iloc[:,1],
    '2018绿化覆盖面积（公顷）':df31.iloc[:,1],
    '2018供水普及率%': df32.iloc[:,1],
    '2018农村人均住宅建筑面积 ':df33.iloc[:,1],
    '2018 设有村镇建设管理机构的个数':df41.iloc[:,1],
    '2018有总体规划的乡个数':df42.iloc[:,1],
    '2018 1000人以上行政村个数':df43.iloc[:,1],
    '2018农、林、牧、渔业总产值（亿元）':df51.iloc[:,1],
    '2018农村居民人均可支配收入(元)':df52.iloc[:,1],
    '2018农村居民人均消费支出(元)':df53.iloc[:,1]
})

data_norm2 = (data2 - data2.min()) / (data2.max() - data2.min())
p = data_norm2.apply(lambda x: x / x.sum(), axis=0)
w = -np.sum(p * np.log(p)) / np.log(data_norm2.shape[1])
weights = (1 - w) / (1 - p.apply(lambda x: np.sum((x / x.sum()) * np.log(x / x.sum())), axis=0))
data_weighted = data_norm2 * weights
z_plus = data_weighted.max(axis=0)
z_minus = data_weighted.min(axis=0)
d_plus = np.sqrt(np.sum((data_weighted - z_plus) ** 2, axis=1))
d_minus = np.sqrt(np.sum((data_weighted - z_minus) ** 2, axis=1))
scores = d_minus / (d_plus + d_minus)
data2['TOSIS综合评价(未排序)'] = scores
print(data2)
# Out:
#     2018各地村卫生室个数  2018农村居民教育文化支出占比%  2018主要农作物粮食产量（万吨）  2018农业机械总动力（万千瓦）  \
# 0           2493                7.1              34.14             125.7
# 1           2511                7.3             209.69             348.0
# 2          59047               10.3            3700.86            7706.2
# 3          28338               12.5            1380.40            1441.1
# 4          13539               13.7            3553.28            3663.7
# 5          19127               11.6            2192.45            2243.7
# 6           9901               13.0            3632.74            3466.0
# 7          10740               12.4            7506.80            6084.7
# 8           1162                5.9             103.74              94.0
# 9          15311                9.3            3660.28            5017.7
# 10         11483                9.1             599.14            2009.3
# 11         15317               10.0            4007.25            6543.8
# ...

# %%
data2.to_excel('2018TOPSIS.xlsx',index=False)

# %%
data3 = pd.DataFrame({
    '2019各地村卫生室个数':df11.iloc[:,2],
    '2019农村居民教育文化支出占比%': df12.iloc[:,2],
    '2019主要农作物粮食产量（万吨）': df21.iloc[:,2],
    '2019农业机械总动力（万千瓦）':df22.iloc[:,2],
    '2019绿化覆盖面积（公顷）':df31.iloc[:,2],
    '2019供水普及率%': df32.iloc[:,2],
    '2019农村人均住宅建筑面积 ':df33.iloc[:,2],
    '2019 设有村镇建设管理机构的个数':df41.iloc[:,2],
    '2019有总体规划的乡个数':df42.iloc[:,2],
    '2019 1000人以上行政村个数':df43.iloc[:,2],
    '2019农、林、牧、渔业总产值（亿元）':df51.iloc[:,2],
    '2019农村居民人均可支配收入(元)':df52.iloc[:,2],
    '2019农村居民人均消费支出(元)':df53.iloc[:,2]
})

data_norm3 = (data3 - data3.min()) / (data3.max() - data3.min())
p = data_norm3.apply(lambda x: x / x.sum(), axis=0)
w = -np.sum(p * np.log(p)) / np.log(data_norm3.shape[1])
weights = (1 - w) / (1 - p.apply(lambda x: np.sum((x / x.sum()) * np.log(x / x.sum())), axis=0))
data_weighted = data_norm3 * weights
z_plus = data_weighted.max(axis=0)
z_minus = data_weighted.min(axis=0)
d_plus = np.sqrt(np.sum((data_weighted - z_plus) ** 2, axis=1))
d_minus = np.sqrt(np.sum((data_weighted - z_minus) ** 2, axis=1))
scores = d_minus / (d_plus + d_minus)
data3['TOSIS综合评价(未排序)'] = scores
print(data3)
# Out:
#     2019各地村卫生室个数  2019农村居民教育文化支出占比%  2019主要农作物粮食产量（万吨）  2019农业机械总动力（万千瓦）  \
# 0           2449                9.2              28.76             122.8
# 1           2374                8.9             223.25             359.8
# 2          59526               12.7            3739.24            7830.7
# 3          28106               14.7            1361.80            1517.6
# 4          13321               15.0            3652.54            3866.4
# 5          17963               13.9            2429.95            2353.9
# 6           9615               15.8            3877.93            3653.7
# 7          10448               16.1            7503.01            6359.1
# 8           1179                7.9              95.89              98.0
# 9          15169               11.4            3706.20            5112.0
# 10         11590               13.3             592.15            1908.0
# 11         15549               12.5            4054.00            6650.5
# ...

# %%
data3.to_excel('2019TOPSIS.xlsx',index=False)

# %%
data4 = pd.DataFrame({
    '2020各地村卫生室个数':df11.iloc[:,3],
    '2020农村居民教育文化支出占比%': df12.iloc[:,3],
    '2020主要农作物粮食产量（万吨）': df21.iloc[:,3],
    '2020农业机械总动力（万千瓦）':df22.iloc[:,3],
    '2020绿化覆盖面积（公顷）':df31.iloc[:,3],
    '2020供水普及率%': df32.iloc[:,3],
    '2020农村人均住宅建筑面积 ':df33.iloc[:,3],
    '2020 设有村镇建设管理机构的个数':df41.iloc[:,3],
    '2020有总体规划的乡个数':df42.iloc[:,3],
    '2020 1000人以上行政村个数':df43.iloc[:,3],
    '2020农、林、牧、渔业总产值（亿元）':df51.iloc[:,3],
    '2020农村居民人均可支配收入(元)':df52.iloc[:,3],
    '2020农村居民人均消费支出(元)':df53.iloc[:,3]
})


data_norm4 = (data4 - data4.min()) / (data4.max() - data4.min())
p = data_norm4.apply(lambda x: x / x.sum(), axis=0)
w = -np.sum(p * np.log(p)) / np.log(data_norm4.shape[1])
weights = (1 - w) / (1 - p.apply(lambda x: np.sum((x / x.sum()) * np.log(x / x.sum())), axis=0))
data_weighted = data_norm4 * weights
z_plus = data_weighted.max(axis=0)
z_minus = data_weighted.min(axis=0)
d_plus = np.sqrt(np.sum((data_weighted - z_plus) ** 2, axis=1))
d_minus = np.sqrt(np.sum((data_weighted - z_minus) ** 2, axis=1))
scores = d_minus / (d_plus + d_minus)
data4['TOSIS综合评价(未排序)'] = scores
print(data4)
# Out:
#     2020各地村卫生室个数  2020农村居民教育文化支出占比%  2020主要农作物粮食产量（万吨）  2020农业机械总动力（万千瓦）  \
# 0           2472                7.1              30.53             120.2
# 1           2196                6.5             228.18             365.1
# 2          60183               10.5            3795.89            7965.7
# 3          26800               11.2            1424.27            1595.3
# 4          13030               12.5            3664.10            4056.6
# 5          17567               10.6            2338.83            2471.3
# 6           9638               11.8            3803.17            3896.9
# 7          10385               11.1            7540.78            6775.1
# 8           1169                5.4              91.44             102.1
# 9          15020               10.4            3729.06            5213.8
# 10         11300               10.4             605.70            1813.2
# 11         15710               11.6            4019.22            6799.5
# ...

# %%
data4.to_excel('2020TOPSIS.xlsx',index=False)

# %%
data5 = pd.DataFrame({
    '2021各地村卫生室个数':df11.iloc[:,4],
    '2021农村居民教育文化支出占比%': df12.iloc[:,4],
    '2021主要农作物粮食产量（万吨）': df21.iloc[:,4],
    '2021农业机械总动力（万千瓦）':df22.iloc[:,4],
    '2021绿化覆盖面积（公顷）':df31.iloc[:,4],
    '2021供水普及率%': df32.iloc[:,4],
    '2021农村人均住宅建筑面积 ':df33.iloc[:,4],
    '2021 设有村镇建设管理机构的个数':df41.iloc[:,4],
    '2021有总体规划的乡个数':df42.iloc[:,4],
    '2021 1000人以上行政村个数':df43.iloc[:,4],
    '2021农、林、牧、渔业总产值（亿元）':df51.iloc[:,4],
    '2021农村居民人均可支配收入(元)':df52.iloc[:,4],
    '2021农村居民人均消费支出(元)':df53.iloc[:,4]
})


data_norm5 = (data5 - data5.min()) / (data5.max() - data5.min())
p = data_norm5.apply(lambda x: x / x.sum(), axis=0)
w = -np.sum(p * np.log(p)) / np.log(data_norm5.shape[1])
weights = (1 - w) / (1 - p.apply(lambda x: np.sum((x / x.sum()) * np.log(x / x.sum())), axis=0))
data_weighted = data_norm5 * weights
z_plus = data_weighted.max(axis=0)
z_minus = data_weighted.min(axis=0)
d_plus = np.sqrt(np.sum((data_weighted - z_plus) ** 2, axis=1))
d_minus = np.sqrt(np.sum((data_weighted - z_minus) ** 2, axis=1))
scores = d_minus / (d_plus + d_minus)
data5['TOSIS综合评价(未排序)'] = scores
print(data5)
# Out:
#     2021各地村卫生室个数  2021农村居民教育文化支出占比%  2021主要农作物粮食产量（万吨）  2021农业机械总动力（万千瓦）  \
# 0           2559                7.3              37.75             121.2
# 1           2214                8.6             249.87             372.5
# 2          59967               11.5            3825.09            8096.8
# 3          26355               11.7            1421.25            1654.2
# 4          12965               12.7            3840.30            4239.4
# 5          16235               13.0            2538.74            2552.6
# 6           9463               14.7            4039.24            4149.2
# 7          10128               11.9            7867.72            6912.1
# 8           1147                5.7              93.96             102.7
# 9          14936               10.7            3746.10            5148.2
# 10         11221               11.4             620.90            1773.7
# 11         15630               14.1            4087.56            6924.3
# ...

# %%
data5.to_excel('2021TOPSIS.xlsx',index=False)

# %% [markdown]
# # 一级指标

# %%
import pandas as pd
import numpy as np
data = pd.DataFrame({
    '2017各地村卫生室个数':df11.iloc[:,0],
    '2017农村居民教育文化支出占比%': df12.iloc[:,0],
    '2017主要农作物粮食产量（万吨）': df21.iloc[:,0],
    '2017农业机械总动力（万千瓦）':df22.iloc[:,0],
    '2017绿化覆盖面积（公顷）':df31.iloc[:,0],
    '2017供水普及率%': df32.iloc[:,0],
    '2017农村人均住宅建筑面积 ':df33.iloc[:,0],
    '2017 设有村镇建设管理机构的个数':df41.iloc[:,0],
    '2017有总体规划的乡个数':df42.iloc[:,0],
    '2017 1000人以上行政村个数':df43.iloc[:,0],
    '2017农、林、牧、渔业总产值（亿元）':df51.iloc[:,0],
    '2017农村居民人均可支配收入(元)':df52.iloc[:,0],
    '2017农村居民人均消费支出(元)':df53.iloc[:,0]
})
# 正向化处理
data_norm = (data - data.min()) / (data.max() - data.min())
# 计算信息熵
E = -1 * (data_norm * np.log2(data_norm)).sum() / np.log2(data_norm.shape[0])
# 计算权重
w = (1 - np.exp(-1 * E)) / np.sum(1 - np.exp(-1 * E))
# 归一化处理
w_norm = w / np.sum(w)
# Out:
# D:\anaconda\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log2
#   result = func(self.values, **kwargs)

# %%
w_norm
# Out:
# 2017各地村卫生室个数           0.076643
# 2017农村居民教育文化支出占比%      0.078325
# 2017主要农作物粮食产量（万吨）      0.075896
# 2017农业机械总动力（万千瓦）       0.076975
# 2017绿化覆盖面积（公顷）         0.073117
# 2017供水普及率%             0.074362
# 2017农村人均住宅建筑面积         0.078982
# 2017 设有村镇建设管理机构的个数     0.075771
# 2017有总体规划的乡个数          0.076041
# 2017 1000人以上行政村个数      0.077874
# 2017农、林、牧、渔业总产值（亿元）    0.077483
# 2017农村居民人均可支配收入(元)     0.078974
# 2017农村居民人均消费支出(元)      0.079557
# dtype: float64

# %%
w_norm[1]
# Out:
# 0.07832467822746782

# %%
df1t = w_norm[0] * data1['TOSIS综合评价(未排序)'] + w_norm[1] * data1['TOSIS综合评价(未排序)']
df2t = w_norm[2] * data1['TOSIS综合评价(未排序)'] + w_norm[3] * data1['TOSIS综合评价(未排序)']
df3t = w_norm[4] * data1['TOSIS综合评价(未排序)'] + w_norm[5] * data1['TOSIS综合评价(未排序)'] + w_norm[6] * data1['TOSIS综合评价(未排序)']
df4t = w_norm[7] * data1['TOSIS综合评价(未排序)'] + w_norm[8] * data1['TOSIS综合评价(未排序)'] + w_norm[9] * data1['TOSIS综合评价(未排序)']
df5t = w_norm[10] * data1['TOSIS综合评价(未排序)'] + w_norm[11] * data1['TOSIS综合评价(未排序)'] + w_norm[12] * data1['TOSIS综合评价(未排序)']

df1t.to_excel('2017一级_乡风文化TOPSIS法评分.xlsx', index=False)
df2t.to_excel('2017一级_产业兴旺TOPSIS法评分.xlsx', index=False)
df3t.to_excel('2017一级_生态宜居TOPSIS法评分.xlsx', index=False)
df4t.to_excel('2017一级_治理有效TOPSIS法评分.xlsx', index=False)
df5t.to_excel('2017一级_生活富裕TOPSIS法评分.xlsx', index=False)

# %%
data = pd.DataFrame({
    '2018各地村卫生室个数':df11.iloc[:,1],
    '2018农村居民教育文化支出占比%': df12.iloc[:,1],
    '2018主要农作物粮食产量（万吨）': df21.iloc[:,1],
    '2018农业机械总动力（万千瓦）':df22.iloc[:,1],
    '2018绿化覆盖面积（公顷）':df31.iloc[:,1],
    '2018供水普及率%': df32.iloc[:,1],
    '2018农村人均住宅建筑面积 ':df33.iloc[:,1],
    '2018 设有村镇建设管理机构的个数':df41.iloc[:,1],
    '2018有总体规划的乡个数':df42.iloc[:,1],
    '2018 1000人以上行政村个数':df43.iloc[:,1],
    '2018农、林、牧、渔业总产值（亿元）':df51.iloc[:,1],
    '2018农村居民人均可支配收入(元)':df52.iloc[:,1],
    '2018农村居民人均消费支出(元)':df53.iloc[:,1]
})
# 正向化处理
data_norm = (data - data.min()) / (data.max() - data.min())
# 计算信息熵
E = -1 * (data_norm * np.log2(data_norm)).sum() / np.log2(data_norm.shape[0])
# 计算权重
w = (1 - np.exp(-1 * E)) / np.sum(1 - np.exp(-1 * E))
# 归一化处理
w_norm = w / np.sum(w)

# %%
df1t = w_norm[0] * data2['TOSIS综合评价(未排序)'] + w_norm[1] * data2['TOSIS综合评价(未排序)']
df2t = w_norm[2] * data2['TOSIS综合评价(未排序)'] + w_norm[3] * data2['TOSIS综合评价(未排序)']
df3t = w_norm[4] * data2['TOSIS综合评价(未排序)'] + w_norm[5] * data2['TOSIS综合评价(未排序)'] + w_norm[6] * data2['TOSIS综合评价(未排序)']
df4t = w_norm[7] * data2['TOSIS综合评价(未排序)'] + w_norm[8] * data2['TOSIS综合评价(未排序)'] + w_norm[9] * data2['TOSIS综合评价(未排序)']
df5t = w_norm[10] * data2['TOSIS综合评价(未排序)'] + w_norm[11] * data2['TOSIS综合评价(未排序)'] + w_norm[12] * data2['TOSIS综合评价(未排序)']

df1t.to_excel('2018一级_乡风文化TOPSIS法评分.xlsx', index=False)
df2t.to_excel('2018一级_产业兴旺TOPSIS法评分.xlsx', index=False)
df3t.to_excel('2018一级_生态宜居TOPSIS法评分.xlsx', index=False)
df4t.to_excel('2018一级_治理有效TOPSIS法评分.xlsx', index=False)
df5t.to_excel('2018一级_生活富裕TOPSIS法评分.xlsx', index=False)

# %%
data = pd.DataFrame({
    '2019各地村卫生室个数':df11.iloc[:,2],
    '2019农村居民教育文化支出占比%': df12.iloc[:,2],
    '2019主要农作物粮食产量（万吨）': df21.iloc[:,2],
    '2019农业机械总动力（万千瓦）':df22.iloc[:,2],
    '2019绿化覆盖面积（公顷）':df31.iloc[:,2],
    '2019供水普及率%': df32.iloc[:,2],
    '2019农村人均住宅建筑面积 ':df33.iloc[:,2],
    '2019 设有村镇建设管理机构的个数':df41.iloc[:,2],
    '2019有总体规划的乡个数':df42.iloc[:,2],
    '2019 1000人以上行政村个数':df43.iloc[:,2],
    '2019农、林、牧、渔业总产值（亿元）':df51.iloc[:,2],
    '2019农村居民人均可支配收入(元)':df52.iloc[:,2],
    '2019农村居民人均消费支出(元)':df53.iloc[:,2]
})
# 正向化处理
data_norm = (data - data.min()) / (data.max() - data.min())
# 计算信息熵
E = -1 * (data_norm * np.log2(data_norm)).sum() / np.log2(data_norm.shape[0])
# 计算权重
w = (1 - np.exp(-1 * E)) / np.sum(1 - np.exp(-1 * E))
# 归一化处理
w_norm = w / np.sum(w)

# %%
df1t = w_norm[0] * data3['TOSIS综合评价(未排序)'] + w_norm[1] * data3['TOSIS综合评价(未排序)']
df2t = w_norm[2] * data3['TOSIS综合评价(未排序)'] + w_norm[3] * data3['TOSIS综合评价(未排序)']
df3t = w_norm[4] * data3['TOSIS综合评价(未排序)'] + w_norm[5] * data3['TOSIS综合评价(未排序)'] + w_norm[6] * data3['TOSIS综合评价(未排序)']
df4t = w_norm[7] * data3['TOSIS综合评价(未排序)'] + w_norm[8] * data3['TOSIS综合评价(未排序)'] + w_norm[9] * data3['TOSIS综合评价(未排序)']
df5t = w_norm[10] * data3['TOSIS综合评价(未排序)'] + w_norm[11] * data3['TOSIS综合评价(未排序)'] + w_norm[12] * data3['TOSIS综合评价(未排序)']

df1t.to_excel('2019一级_乡风文化TOPSIS法评分.xlsx', index=False)
df2t.to_excel('2019一级_产业兴旺TOPSIS法评分.xlsx', index=False)
df3t.to_excel('2019一级_生态宜居TOPSIS法评分.xlsx', index=False)
df4t.to_excel('2019一级_治理有效TOPSIS法评分.xlsx', index=False)
df5t.to_excel('2019一级_生活富裕TOPSIS法评分.xlsx', index=False)

# %%
data = pd.DataFrame({
    '2020各地村卫生室个数':df11.iloc[:,3],
    '2020农村居民教育文化支出占比%': df12.iloc[:,3],
    '2020主要农作物粮食产量（万吨）': df21.iloc[:,3],
    '2020农业机械总动力（万千瓦）':df22.iloc[:,3],
    '2020绿化覆盖面积（公顷）':df31.iloc[:,3],
    '2020供水普及率%': df32.iloc[:,3],
    '2020农村人均住宅建筑面积 ':df33.iloc[:,3],
    '2020 设有村镇建设管理机构的个数':df41.iloc[:,3],
    '2020有总体规划的乡个数':df42.iloc[:,3],
    '2020 1000人以上行政村个数':df43.iloc[:,3],
    '2020农、林、牧、渔业总产值（亿元）':df51.iloc[:,3],
    '2020农村居民人均可支配收入(元)':df52.iloc[:,3],
    '2020农村居民人均消费支出(元)':df53.iloc[:,3]
})
# 正向化处理
data_norm = (data - data.min()) / (data.max() - data.min())
# 计算信息熵
E = -1 * (data_norm * np.log2(data_norm)).sum() / np.log2(data_norm.shape[0])
# 计算权重
w = (1 - np.exp(-1 * E)) / np.sum(1 - np.exp(-1 * E))
# 归一化处理
w_norm = w / np.sum(w)

# %%
df1t = w_norm[0] * data4['TOSIS综合评价(未排序)'] + w_norm[1] * data4['TOSIS综合评价(未排序)']
df2t = w_norm[2] * data4['TOSIS综合评价(未排序)'] + w_norm[3] * data4['TOSIS综合评价(未排序)']
df3t = w_norm[4] * data4['TOSIS综合评价(未排序)'] + w_norm[5] * data4['TOSIS综合评价(未排序)'] + w_norm[6] * data4['TOSIS综合评价(未排序)']
df4t = w_norm[7] * data4['TOSIS综合评价(未排序)'] + w_norm[8] * data4['TOSIS综合评价(未排序)'] + w_norm[9] * data4['TOSIS综合评价(未排序)']
df5t = w_norm[10] * data4['TOSIS综合评价(未排序)'] + w_norm[11] * data4['TOSIS综合评价(未排序)'] + w_norm[12] * data4['TOSIS综合评价(未排序)']

df1t.to_excel('2020一级_乡风文化TOPSIS法评分.xlsx', index=False)
df2t.to_excel('2020一级_产业兴旺TOPSIS法评分.xlsx', index=False)
df3t.to_excel('2020一级_生态宜居TOPSIS法评分.xlsx', index=False)
df4t.to_excel('2020一级_治理有效TOPSIS法评分.xlsx', index=False)
df5t.to_excel('2020一级_生活富裕TOPSIS法评分.xlsx', index=False)

# %%
data = pd.DataFrame({
    '2021各地村卫生室个数':df11.iloc[:,4],
    '2021农村居民教育文化支出占比%': df12.iloc[:,4],
    '2021主要农作物粮食产量（万吨）': df21.iloc[:,4],
    '2021农业机械总动力（万千瓦）':df22.iloc[:,4],
    '2021绿化覆盖面积（公顷）':df31.iloc[:,4],
    '2021供水普及率%': df32.iloc[:,4],
    '2021农村人均住宅建筑面积 ':df33.iloc[:,4],
    '2021 设有村镇建设管理机构的个数':df41.iloc[:,4],
    '2021有总体规划的乡个数':df42.iloc[:,4],
    '2021 1000人以上行政村个数':df43.iloc[:,4],
    '2021农、林、牧、渔业总产值（亿元）':df51.iloc[:,4],
    '2021农村居民人均可支配收入(元)':df52.iloc[:,4],
    '2021农村居民人均消费支出(元)':df53.iloc[:,4]
})

# 正向化处理
data_norm = (data - data.min()) / (data.max() - data.min())
# 计算信息熵
E = -1 * (data_norm * np.log2(data_norm)).sum() / np.log2(data_norm.shape[0])
# 计算权重
w = (1 - np.exp(-1 * E)) / np.sum(1 - np.exp(-1 * E))
# 归一化处理
w_norm = w / np.sum(w)

# %%
df1t = w_norm[0] * data5['TOSIS综合评价(未排序)'] + w_norm[1] * data5['TOSIS综合评价(未排序)']
df2t = w_norm[2] * data5['TOSIS综合评价(未排序)'] + w_norm[3] * data5['TOSIS综合评价(未排序)']
df3t = w_norm[4] * data5['TOSIS综合评价(未排序)'] + w_norm[5] * data5['TOSIS综合评价(未排序)'] + w_norm[6] * data5['TOSIS综合评价(未排序)']
df4t = w_norm[7] * data5['TOSIS综合评价(未排序)'] + w_norm[8] * data5['TOSIS综合评价(未排序)'] + w_norm[9] * data5['TOSIS综合评价(未排序)']
df5t = w_norm[10] * data5['TOSIS综合评价(未排序)'] + w_norm[11] * data5['TOSIS综合评价(未排序)'] + w_norm[12] * data5['TOSIS综合评价(未排序)']

df1t.to_excel('2021一级_乡风文化TOPSIS法评分.xlsx', index=False)
df2t.to_excel('2021一级_产业兴旺TOPSIS法评分.xlsx', index=False)
df3t.to_excel('2021一级_生态宜居TOPSIS法评分.xlsx', index=False)
df4t.to_excel('2021一级_治理有效TOPSIS法评分.xlsx', index=False)
df5t.to_excel('2021一级_生活富裕TOPSIS法评分.xlsx', index=False)

# %%
import libpysal.weights as weights
import matplotlib.pyplot as plt
import esda
import geopandas as gpd
#  pysal.explore.esda as 
# 读取地理空间数据
data = gpd.read_file('中华人民共和国.shp')

# 构建邻接矩阵
w = weights.Queen.from_dataframe(data)

# 计算莫兰指数
moran = esda.Moran(data['adcode'], w)
print(moran.I)
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')
# ('WARNING: ', 31, ' is an island (no neighbors)')
# ('WARNING: ', 34, ' is an island (no neighbors)')
# nan

# %%
import geopandas as gpd

ddd = gpd.read_file('中华人民共和国.shp',encoding='utf-8')
ddd
# Out:
#       adcode      name center centroid  childrenNu     level parent  \
# 0   110000.0       北京市   None     None        16.0  province   None
# 1   120000.0       天津市   None     None        16.0  province   None
# 2   130000.0       河北省   None     None        11.0  province   None
# 3   140000.0       山西省   None     None        11.0  province   None
# 4   150000.0    内蒙古自治区   None     None        12.0  province   None
# 5   210000.0       辽宁省   None     None        14.0  province   None
# 6   220000.0       吉林省   None     None         9.0  province   None
# 7   230000.0      黑龙江省   None     None        13.0  province   None
# 8   310000.0       上海市   None     None        16.0  province   None
# 9   320000.0       江苏省   None     None        13.0  province   None
# 10  330000.0       浙江省   None     None        11.0  province   None
# 11  340000.0       安徽省   None     None        16.0  province   None
# 12  350000.0       福建省   None     None         9.0  province   None
# ...

# %%
ddd.drop(ddd.tail(4).index,inplace=True)

# %%
m1 = pd.read_excel('2017TOPSIS.xlsx')
m1.head(10)
# Out:
#    2017各地村卫生室个数  2017农村居民教育文化支出占比%  2017主要农作物粮食产量（万吨）  2017农业机械总动力（万千瓦）  \
# 0          2696                9.1              41.12             133.5
# 1          2541                9.5             212.27             464.7
# 2         60225               11.1            3829.25            7580.6
# 3         28942               16.3            1355.10            1376.3
# 4         13625               15.6            3254.54            3483.6
# 5         19519               14.0            2330.74            2215.1
# 6         10108               15.2            4154.00            3284.7
# 7         10842               14.6            7410.34            5813.8
# 8          1187                8.5              99.78             121.8
# 9         15319               11.1            3610.80            4991.4
#
#    2017绿化覆盖面积（公顷）  2017供水普及率%  2017农村人均住宅建筑面积   2017 设有村镇建设管理机构的个数  \
# 0          202.99       92.14            45.82                  13
# ...

# %%
# x = m1['地区'] + m1['TOSIS综合评价(未排序)']
x = pd.concat([ddd['name'],m1['TOSIS综合评价(未排序)']],axis=1)

# %%
import libpysal.weights as weights
import matplotlib.pyplot as plt
import esda
import geopandas as gpd
#  pysal.explore.esda as 
# 读取地理空间数据
# data = gpd.read_file('中华人民共和国.shp')

# 构建邻接矩阵
w = weights.Queen.from_dataframe(ddd)

# 计算莫兰指数
moran = esda.Moran(m1['TOSIS综合评价(未排序)'], w)
print("莫兰指数: ", moran.I)
print("p-value: ", moran.p_sim)
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')
# 莫兰指数:  0.07983595435119002
# p-value:  0.163

# %%
from splot.esda import plot_moran
# pysal.viz.splot.esda
plot_moran(moran)
# Out:
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.08', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.08)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))

# %%
from splot.esda import moran_scatterplot

fig, ax = moran_scatterplot(moran, aspect_equal=True)
ax.set_xlabel("score")
ax.set_ylabel("moran")
plt.show()

# %%
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif']=['Microsoft YaHei']

# %%
import geopandas as gpd
import pandas as pd
import pysal.lib
from pysal.explore import esda
from pysal.lib import weights
import matplotlib.pyplot as plt

# # 加载乡村振兴得分数据
# data = pd.read_csv('path/to/data.csv')

# # 加载省市边界数据
# province = gpd.read_file('path/to/province.shp')

# # 根据省市边界数据构建邻接矩阵
# w = weights.Queen.from_dataframe(province)

# 计算乡村振兴得分的莫兰指数
moran = esda.Moran(m1['TOSIS综合评价(未排序)'], w)

# 绘制莫兰散点图，并在每个散点上添加省市信息
fig, ax = moran_scatterplot(moran, p=0.05)
for i, txt in enumerate(ddd['name']):
    ax.annotate(txt, (moran.z[i], m1['TOSIS综合评价(未排序)'].iloc[i]),fontsize=8)
plt.show()

# %%
xx = pd.concat([m1['TOSIS综合评价(未排序)'],ddd['geometry']],axis=1)
xx
# Out:
#     TOSIS综合评价(未排序)                                           geometry
# 0         0.264371  POLYGON ((117.38988 40.22796, 117.38372 40.188...
# 1         0.193556  MULTIPOLYGON (((117.76560 39.40053, 117.69970 ...
# 2         0.358309  MULTIPOLYGON (((115.72253 39.54420, 115.72130 ...
# 3         0.154704  POLYGON ((110.37926 34.60061, 110.29549 34.610...
# 4         0.110135  POLYGON ((97.17290 42.79526, 97.28254 42.78208...
# 5         0.086772  MULTIPOLYGON (((119.85425 39.98857, 119.84563 ...
# 6         0.113570  POLYGON ((125.70752 40.86688, 125.68781 40.897...
# 7         0.265878  POLYGON ((123.17848 46.24824, 123.14214 46.298...
# 8         0.285914  MULTIPOLYGON (((120.90135 31.01733, 120.89088 ...
# 9         0.243796  POLYGON ((119.30607 35.07658, 119.29251 35.068...
# 10        0.309652  MULTIPOLYGON (((118.43390 28.28834, 118.48009 ...
# 11        0.166728  MULTIPOLYGON (((116.19680 34.57598, 116.24793 ...
# ...

# %%
import geopandas as gpd
import pysal.lib as ps
import esda
import matplotlib.pyplot as plt

# 读入数据
data = gpd.read_file('中华人民共和国.shp')

# 计算莫兰指数
w = ps.weights.Queen.from_dataframe(ddd)
moran = esda.Moran(m1['TOSIS综合评价(未排序)'], w)

# 将结果转换为GeoDataFrame类型，并合并到原始数据中
moran_df = gpd.GeoDataFrame(xx)
moran_df['moran'] = moran.I
moran_df = moran_df.dropna()

# 绘制莫兰散点图，并在散点上标注省市名称
fig, ax = plt.subplots(figsize=(10, 8))
moran_df.plot(column='moran', cmap='YlGnBu', markersize=60, ax=ax)
for idx, row in moran_df.iterrows():
    ax.annotate(text=row['TOSIS综合评价(未排序)'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=8)
plt.title('Moran Scatterplot')
plt.show()
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')

# %%
I = moran.I
E = moran.EI
# sd = moran.seI
z = moran.z_norm
p_value = moran.p_norm
print("2017 I",I)
print("2017 E",E)
# print("2017 sd",sd)
print("2017 z",z)
print("2017 p-value",p_value)
# Out:
# 2017 I 0.07983595435119002
# 2017 E -0.03333333333333333
# 2017 z 0.9684399380830416
# 2017 p-value 0.3328247016182604

# %%
yy = pd.concat([ddd['name'],ddd['geometry']],axis=1)

# %%
import geopandas as gpd
import pandas as pd
from splot.esda import moran_scatterplot

# 创建包含名称、几何对象和莫兰指数值的新GeoDataFrame
centers = yy.copy()
centers['moran'] = moran.I

# 创建一个基础地图
basemap = centers.plot(color='white')  # edgecolor='black'

# 将每个省市的名称绘制在地图上
for idx, row in centers.iterrows():
    basemap.annotate(text=row['name'], xy=row['geometry'].centroid.coords[0], 
                     horizontalalignment='center')

# 绘制莫兰散点图
moran_scatterplot(moran, ax=basemap)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:title={'center':'Moran Scatterplot (0.08)'}, xlabel='Attribute', ylabel='Spatial Lag'>)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# # 读取数据和地图文件
# data = pd.read_csv('data.csv')
# map_df = gpd.read_file('china_regions.shp')

# 计算莫兰指数
w = weights.Queen.from_dataframe(ddd)
moran = esda.Moran(m1['TOSIS综合评价(未排序)'], w)

# 获取每个省市的中心点坐标和名称信息
centers = yy.copy()
centers['x'] = centers['geometry'].apply(lambda p: p.centroid.x)
centers['y'] = centers['geometry'].apply(lambda p: p.centroid.y)

# 合并数据和中心点信息
data = pd.concat([m1['TOSIS综合评价(未排序)'],centers[['地区','x','y']]],axis=1)
                  # merge(data, centers[['地区', 'x', 'y']], left_on='province', right_on='NAME_CHN')

# 绘制散点图
fig, ax = plt.subplots(figsize=(10, 8))
sns.scatterplot(data=data, x='TOSIS综合评价(未排序)', y='y', hue='地区', size='x', style='地区', s=150, legend=False)
sns.despine()
plt.xlabel('score')
plt.ylabel('')
plt.title(f'Moran\'s I = {moran.I:.2f}, p = {moran.p_sim:.4f}')
plt.tight_layout()

# 添加省市标签
for i,row in centers.iterrows():
    plt.annotate(row['地区'], (row['x'], row['y']), ha='center', va='center', fontsize=10, fontweight='bold', color='white')
    
plt.show()
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [72], in <cell line: 18>()
#      15 centers['y'] = centers['geometry'].apply(lambda p: p.centroid.y)
#      17 # 合并数据和中心点信息
# ---> 18 data = pd.concat([m1['TOSIS综合评价(未排序)'],centers[['地区','x','y']]],axis=1)
#      19                   # merge(data, centers[['地区', 'x', 'y']], left_on='province', right_on='NAME_CHN')
#      20
#      21 # 绘制散点图
#      22 fig, ax = plt.subplots(figsize=(10, 8))
#
# File D:\anaconda\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
from matplotlib import pyplot as plt
import geopandas as gpd
import pandas as pd
import numpy as np

# # 读取数据并转换为GeoDataFrame格式
# data = pd.read_excel('data.xlsx')
# gdf = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data.x, data.y))

# 构建邻接矩阵并计算莫兰指数
w = weights.Queen.from_dataframe(ddd)
moran = esda.Moran(m1['TOSIS综合评价(未排序)'], w)

plt.figure()
# 绘制莫兰散点图
fig, ax = plt.subplots(figsize=(10, 8))
moran_scatterplot(moran, ax=ax, p=0.05)

# 添加省市名称注释
for i, txt in enumerate(m1['地区']):
    plt.annotate(txt, (data['x'][i], data['y'][i]), xytext=(5, 0), textcoords='offset points',fontsize=8)

plt.show()
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')

# %%
m2 = pd.read_excel('2018TOPSIS.xlsx')
import libpysal.weights as weights
import matplotlib.pyplot as plt
import esda
import geopandas as gpd
#  pysal.explore.esda as 
# 读取地理空间数据
# data = gpd.read_file('中华人民共和国.shp')

# 构建邻接矩阵
w = weights.Queen.from_dataframe(ddd)

# 计算莫兰指数
moran = esda.Moran(m2['TOSIS综合评价(未排序)'], w)
print("莫兰指数: ", moran.I)
print("p-value: ", moran.p_sim)
from splot.esda import plot_moran
# pysal.viz.splot.esda
plot_moran(moran)
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')
# 莫兰指数:  0.056523972184523666
# p-value:  0.205
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.06', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.06)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))

# %%
xx = pd.concat([m2['TOSIS综合评价(未排序)'],ddd['geometry']],axis=1)
xx
# Out:
#     TOSIS综合评价(未排序)                                           geometry
# 0         0.264540  POLYGON ((117.38988 40.22796, 117.38372 40.188...
# 1         0.172989  MULTIPOLYGON (((117.76560 39.40053, 117.69970 ...
# 2         0.329584  MULTIPOLYGON (((115.72253 39.54420, 115.72130 ...
# 3         0.175646  POLYGON ((110.37926 34.60061, 110.29549 34.610...
# 4         0.141042  POLYGON ((97.17290 42.79526, 97.28254 42.78208...
# 5         0.091659  MULTIPOLYGON (((119.85425 39.98857, 119.84563 ...
# 6         0.120612  POLYGON ((125.70752 40.86688, 125.68781 40.897...
# 7         0.271527  POLYGON ((123.17848 46.24824, 123.14214 46.298...
# 8         0.322698  MULTIPOLYGON (((120.90135 31.01733, 120.89088 ...
# 9         0.231628  POLYGON ((119.30607 35.07658, 119.29251 35.068...
# 10        0.302636  MULTIPOLYGON (((118.43390 28.28834, 118.48009 ...
# 11        0.163653  MULTIPOLYGON (((116.19680 34.57598, 116.24793 ...
# ...

# %%
import geopandas as gpd
import pysal.lib as ps
import esda
import matplotlib.pyplot as plt

# 读入数据
data = gpd.read_file('中华人民共和国.shp')

# 计算莫兰指数
w = ps.weights.Queen.from_dataframe(ddd)
moran = esda.Moran(m2['TOSIS综合评价(未排序)'], w)

# 将结果转换为GeoDataFrame类型，并合并到原始数据中
moran_df = gpd.GeoDataFrame(xx)
moran_df['moran'] = moran.I
moran_df = moran_df.dropna()

# 绘制莫兰散点图，并在散点上标注省市名称
fig, ax = plt.subplots(figsize=(10, 8))
moran_df.plot(column='moran', cmap='YlGnBu', markersize=60, ax=ax)
for idx, row in moran_df.iterrows():
    ax.annotate(text=row['TOSIS综合评价(未排序)'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=8)
plt.title('Moran Scatterplot')
plt.show()
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')

# %%
I = moran.I
E = moran.EI
# sd = moran.seI
z = moran.z_norm
p_value = moran.p_norm
print("2018 I",I)
print("2018 E",E)
# print("2018 sd",sd)
print("2018 z",z)
print("2018 p-value",p_value)
# Out:
# 2018 I 0.056523972184523666
# 2018 E -0.03333333333333333
# 2018 z 0.7689489363457674
# 2018 p-value 0.4419236248696121

# %%
m3 = pd.read_excel('2019TOPSIS.xlsx')
import libpysal.weights as weights
import matplotlib.pyplot as plt
import esda
import geopandas as gpd
#  pysal.explore.esda as 
# 读取地理空间数据
# data = gpd.read_file('中华人民共和国.shp')

# 构建邻接矩阵
w = weights.Queen.from_dataframe(ddd)

# 计算莫兰指数
moran = esda.Moran(m3['TOSIS综合评价(未排序)'], w)
print("莫兰指数: ", moran.I)
print("p-value: ", moran.p_sim)
from splot.esda import plot_moran
# pysal.viz.splot.esda
plot_moran(moran)
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')
# 莫兰指数:  0.08056040464563274
# p-value:  0.148
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.08', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.08)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))

# %%
xx = pd.concat([m3['TOSIS综合评价(未排序)'],ddd['geometry']],axis=1)

# %%
import geopandas as gpd
import pysal.lib as ps
import esda
import matplotlib.pyplot as plt

# 读入数据
data = gpd.read_file('中华人民共和国.shp')

# 计算莫兰指数
w = ps.weights.Queen.from_dataframe(ddd)
moran = esda.Moran(m3['TOSIS综合评价(未排序)'], w)

# 将结果转换为GeoDataFrame类型，并合并到原始数据中
moran_df = gpd.GeoDataFrame(xx)
moran_df['moran'] = moran.I
moran_df = moran_df.dropna()

# 绘制莫兰散点图，并在散点上标注省市名称
fig, ax = plt.subplots(figsize=(10, 8))
moran_df.plot(column='moran', cmap='YlGnBu', markersize=60, ax=ax)
for idx, row in moran_df.iterrows():
    ax.annotate(text=row['TOSIS综合评价(未排序)'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=8)
plt.title('Moran Scatterplot')
plt.show()
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')

# %%
I = moran.I
E = moran.EI
# sd = moran.seI
z = moran.z_norm
p_value = moran.p_norm
print("2019 I",I)
print("2019 E",E)
# print("2019 sd",sd)
print("2019 z",z)
print("2019 p-value",p_value)
# Out:
# 2019 I 0.08056040464563274
# 2019 E -0.03333333333333333
# 2019 z 0.9746393815243587
# 2019 p-value 0.3297391716766487

# %%
m4 = pd.read_excel('2020TOPSIS.xlsx')
import libpysal.weights as weights
import matplotlib.pyplot as plt
import esda
import geopandas as gpd
#  pysal.explore.esda as 
# 读取地理空间数据
# data = gpd.read_file('中华人民共和国.shp')

# 构建邻接矩阵
w = weights.Queen.from_dataframe(ddd)

# 计算莫兰指数
moran = esda.Moran(m4['TOSIS综合评价(未排序)'], w)
print("莫兰指数: ", moran.I)
print("p-value: ", moran.p_sim)
from splot.esda import plot_moran
# pysal.viz.splot.esda
plot_moran(moran)
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')
# 莫兰指数:  0.11834872185545081
# p-value:  0.093
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.12', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.12)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))

# %%
xx = pd.concat([m4['TOSIS综合评价(未排序)'],ddd['geometry']],axis=1)

# %%
import geopandas as gpd
import pysal.lib as ps
import esda
import matplotlib.pyplot as plt

# 读入数据
data = gpd.read_file('中华人民共和国.shp')

# 计算莫兰指数
w = ps.weights.Queen.from_dataframe(ddd)
moran = esda.Moran(m4['TOSIS综合评价(未排序)'], w)

# 将结果转换为GeoDataFrame类型，并合并到原始数据中
moran_df = gpd.GeoDataFrame(xx)
moran_df['moran'] = moran.I
moran_df = moran_df.dropna()

# 绘制莫兰散点图，并在散点上标注省市名称
fig, ax = plt.subplots(figsize=(10, 8))
moran_df.plot(column='moran', cmap='YlGnBu', markersize=60, ax=ax)
for idx, row in moran_df.iterrows():
    ax.annotate(text=row['TOSIS综合评价(未排序)'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=8)
plt.title('Moran Scatterplot')
plt.show()
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')

# %%
I = moran.I
E = moran.EI
# sd = moran.seI
z = moran.z_norm
p_value = moran.p_norm
print("2020 I",I)
print("2020 E",E)
# print("2020 sd",sd)
print("2020 z",z)
print("2020 p-value",p_value)
# Out:
# 2020 I 0.11834872185545081
# 2020 E -0.03333333333333333
# 2020 z 1.2980108220246709
# 2020 p-value 0.19428361623807922

# %%
m5 = pd.read_excel('2021TOPSIS.xlsx')
import libpysal.weights as weights
import matplotlib.pyplot as plt
import esda
import geopandas as gpd
#  pysal.explore.esda as 
# 读取地理空间数据
# data = gpd.read_file('中华人民共和国.shp')

# 构建邻接矩阵
w = weights.Queen.from_dataframe(ddd)

# 计算莫兰指数
moran = esda.Moran(m5['TOSIS综合评价(未排序)'], w)
print("莫兰指数: ", moran.I)
print("p-value: ", moran.p_sim)
from splot.esda import plot_moran
# pysal.viz.splot.esda
plot_moran(moran)
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')
# 莫兰指数:  0.1323514910124032
# p-value:  0.07
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.13', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.13)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))

# %%
xx = pd.concat([m5['TOSIS综合评价(未排序)'],ddd['geometry']],axis=1)

# %%
import geopandas as gpd
import pysal.lib as ps
import esda
import matplotlib.pyplot as plt

# 读入数据
data = gpd.read_file('中华人民共和国.shp')

# 计算莫兰指数
w = ps.weights.Queen.from_dataframe(ddd)
moran = esda.Moran(m5['TOSIS综合评价(未排序)'], w)

# 将结果转换为GeoDataFrame类型，并合并到原始数据中
moran_df = gpd.GeoDataFrame(xx)
moran_df['moran'] = moran.I
moran_df = moran_df.dropna()

# 绘制莫兰散点图，并在散点上标注省市名称
fig, ax = plt.subplots(figsize=(10, 8))
moran_df.plot(column='moran', cmap='YlGnBu', markersize=60, ax=ax)
for idx, row in moran_df.iterrows():
    ax.annotate(text=row['TOSIS综合评价(未排序)'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=8)
plt.title('Moran Scatterplot')
plt.show()
# Out:
# ('WARNING: ', 20, ' is an island (no neighbors)')

# %%
I = moran.I
E = moran.EI
# sd = moran.seI
z = moran.z_norm
p_value = moran.p_norm
print("2021 I",I)
print("2021 E",E)
# print("2021 sd",sd)
print("2021 z",z)
print("2021 p-value",p_value)
# Out:
# 2021 I 0.1323514910124032
# 2021 E -0.03333333333333333
# 2021 z 1.417838746833679
# 2021 p-value 0.15623784892830805

# %%
import numpy as np # 线性代数
import pandas as pd # 数据处理及CSV文件的读写(例如 pd.read_csv)
import matplotlib.pyplot as plt # 常规画图
import seaborn as sns # 图形渲染好
from sklearn.decomposition import PCA, KernelPCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import VarianceThreshold, RFE, SelectKBest, chi2
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from  sklearn.model_selection import GridSearchCV

# %%
pred = pd.read_excel("topsis_pre1.xlsx")
pred1 = pd.read_excel("topsis_pre1.xlsx")

pred.head(10)
# Out:
#    地区    年份  各地村卫生室个数  农村居民教育文化支出占比%  主要农作物粮食产量（万吨）  农业机械总动力（万千瓦）  绿化覆盖面积（公顷）  \
# 0  北京  2017      2696            9.1          41.12         133.5      202.99
# 1  北京  2018      2493            7.1          34.14         125.7      109.32
# 2  北京  2019      2449            9.2          28.76         122.8      155.61
# 3  北京  2020      2472            7.1          30.53         120.2      156.61
# 4  北京  2021      2559            7.3          37.75         121.2      159.41
# 5  天津  2017      2541            9.5         212.27         464.7       85.12
# 6  天津  2018      2511            7.3         209.69         348.0       68.92
# 7  天津  2019      2374            8.9         223.25         359.8       68.92
# 8  天津  2020      2196            6.5         228.18         365.1       73.12
# 9  天津  2021      2214            8.6         249.87         372.5       73.12
#
#       供水普及率%  农村人均住宅建筑面积   设有村镇建设管理机构的个数  有总体规划的乡个数  1000人以上行政村个数  \
# ...

# %%
dic1 = {}
list1 = []
for i in pred['地区']:
    if i not in list1:
        list1.append(i)
for i in range(1,len(list1)+1):
    dic1.setdefault(list1[i-1],i)
pred['地区'] = pred['地区'].map(dic1)

# %%
pred.head(10)
# Out:
#    地区    年份  各地村卫生室个数  农村居民教育文化支出占比%  主要农作物粮食产量（万吨）  农业机械总动力（万千瓦）  绿化覆盖面积（公顷）  \
# 0   1  2017      2696            9.1          41.12         133.5      202.99
# 1   1  2018      2493            7.1          34.14         125.7      109.32
# 2   1  2019      2449            9.2          28.76         122.8      155.61
# 3   1  2020      2472            7.1          30.53         120.2      156.61
# 4   1  2021      2559            7.3          37.75         121.2      159.41
# 5   2  2017      2541            9.5         212.27         464.7       85.12
# 6   2  2018      2511            7.3         209.69         348.0       68.92
# 7   2  2019      2374            8.9         223.25         359.8       68.92
# 8   2  2020      2196            6.5         228.18         365.1       73.12
# 9   2  2021      2214            8.6         249.87         372.5       73.12
#
#       供水普及率%  农村人均住宅建筑面积   设有村镇建设管理机构的个数  有总体规划的乡个数  1000人以上行政村个数  \
# ...

# %%
pred.columns
# Out:
# Index(['地区', '年份', '各地村卫生室个数', '农村居民教育文化支出占比%', '主要农作物粮食产量（万吨）',
#        '农业机械总动力（万千瓦）', '绿化覆盖面积（公顷）', '供水普及率%', '农村人均住宅建筑面积 ', '设有村镇建设管理机构的个数',
#        '有总体规划的乡个数', '1000人以上行政村个数', '农、林、牧、渔业总产值（亿元）', '农村居民人均可支配收入(元)',
#        '农村居民人均消费支出(元)', 'TOSIS综合评价(未排序)'],
#       dtype='object')

# %%
# x,y = np.split(credit, (11,), axis=1)
x = pred.drop('TOSIS综合评价(未排序)',axis=1)
y = pred['TOSIS综合评价(未排序)']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
print(y_train.value_counts()/len(y_train))
print(y_test.value_counts()/len(y_test))
# Out:
# 0.109054    0.009259
# 0.196809    0.009259
# 0.298552    0.009259
# 0.142038    0.009259
# 0.163566    0.009259
#               ...
# 0.129510    0.009259
# 0.166966    0.009259
# 0.129047    0.009259
# 0.301843    0.009259
# 0.110387    0.009259
# Name: TOSIS综合评价(未排序), Length: 108, dtype: float64
# 0.155293    0.021277
# 0.166166    0.021277
# 0.117195    0.021277
# 0.243796    0.021277
# 0.234361    0.021277
# 0.174454    0.021277
# 0.108192    0.021277
# 0.112730    0.021277
# 0.231979    0.021277
# 0.167305    0.021277
# 0.106687    0.021277
# 0.302636    0.021277
# 0.295551    0.021277
# 0.091659    0.021277
# 0.142754    0.021277
# 0.529328    0.021277
# 0.163653    0.021277
# 0.271527    0.021277
# 0.278542    0.021277
# 0.123578    0.021277
# 0.166728    0.021277
# 0.243555    0.021277
# 0.120533    0.021277
# 0.118556    0.021277
# 0.112286    0.021277
# 0.142616    0.021277
# 0.120612    0.021277
# 0.095561    0.021277
# 0.183728    0.021277
# 0.157700    0.021277
# ...

# %%
from sklearn import linear_model

model = linear_model.LinearRegression()
model.fit(x,y)
y_pred = model.predict(x_test)

print('Intercept: %.2f'
      % model.intercept_)
print('Coefficients: ')
print(model.coef_)
print('Residual sum of squares: %.2f'
      % np.mean((model.predict(x) - y) ** 2))
print('Variance score: %.2f' % model.score(x, y))
# print("得分：",model.score(x,y))
# Out:
# Intercept: 20.35
# Coefficients:
# [ 3.92374877e-03 -1.03379288e-02  1.83638238e-06  1.30374628e-03
#   3.48549518e-05 -2.95782284e-08  4.15871713e-06  3.06728218e-03
#   1.06537593e-03  2.28808520e-04 -6.47202677e-05  6.59869753e-06
#  -1.88554339e-05  1.60920291e-05 -3.96724409e-06]
# Residual sum of squares: 0.00
# Variance score: 0.92

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVC, SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn import svm 
from sklearn import ensemble
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

from sklearn import svm 
from sklearn import ensemble
from sklearn import metrics
model = SVR()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# print('Intercept: %.2f'
#       % model.intercept_)
# print('Coefficients: ')
# print(model.coef_)
# print('Residual sum of squares: %.2f'
#       % np.mean((model.predict(x) - y) ** 2))
# print('Variance score: %.2f' % model.score(x, y))
# print('Intercept: %.2f'
#       % model.intercept_)
# print('Coefficients: ')
# print(model.coef_)
# print('Residual sum of squares: %.2f'
#       % np.mean((model.predict(x) - y) ** 2))
# print('Variance score: %.2f' % model.score(x, y))

# %%
importances = model.feature_importances_
for i, feature in enumerate(x.columns):
    print("{}: {}".format(feature, importances[i]))
    
# 在测试集上预测并计算 R^2 分数
r2 = model.score(x_test, y_test)
# 打印 R^2 分数
print('\n')
print(f"R^2 分数为: {r2:.2f}")
# print("得分：",model.score(x,y))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [100], in <cell line: 1>()
# ----> 1 importances = model.feature_importances_
#       2 for i, feature in enumerate(x.columns):
#       3     print("{}: {}".format(feature, importances[i]))
#
# AttributeError: 'SVR' object has no attribute 'feature_importances_'

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(y_test, model.predict(x_test))
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 0.004030568843681228
# RMSE: 0.06348676116861868

# %%
from sklearn import svm 
from sklearn import ensemble
from sklearn import metrics
model = RandomForestRegressor()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# print('Intercept: %.2f'
#       % model.intercept_)
# print('Coefficients: ')
# print(model.coef_)
# print('Residual sum of squares: %.2f'
#       % np.mean((model.predict(x) - y) ** 2))
# print('Variance score: %.2f' % model.score(x, y))

# %%
importances = model.feature_importances_
for i, feature in enumerate(x.columns):
    print("{}: {}".format(feature, importances[i]))
    
# 在测试集上预测并计算 R^2 分数
r2 = model.score(x_test, y_test)
# 打印 R^2 分数
print('\n')
print(f"R^2 分数为: {r2:.2f}")
# print("得分：",model.score(x,y))
# Out:
# 地区: 0.010324629402303135
# 年份: 0.0028961631422356826
# 各地村卫生室个数: 0.3255397853441419
# 农村居民教育文化支出占比%: 0.009770357027914367
# 主要农作物粮食产量（万吨）: 0.01940355709670863
# 农业机械总动力（万千瓦）: 0.06004463849873135
# 绿化覆盖面积（公顷）: 0.02020133468679973
# 供水普及率%: 0.007590125526675413
# 农村人均住宅建筑面积 : 0.05079682005034916
# 设有村镇建设管理机构的个数: 0.02812667527737959
# 有总体规划的乡个数: 0.009001076419488437
# 1000人以上行政村个数: 0.263207666188666
# 农、林、牧、渔业总产值（亿元）: 0.033668294480208055
# 农村居民人均可支配收入(元): 0.07014012736308652
# 农村居民人均消费支出(元): 0.08928874949531204
#
#
# R^2 分数为: 0.91

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse = mean_squared_error(y_test, model.predict(x_test))
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 0.0011164852766919376
# RMSE: 0.03341384857648005

# %%
# 假设要预测的数据为平均值
new_data = x.mean().values.reshape(1, -1)

# 进行预测
predicted_score = model.predict(new_data)

print('预测的综合得分为：', predicted_score)
# Out:
# 预测的综合得分为： [0.13828903]

# %%
new_data[0][0] = 1

# %%
x.iloc[0:5,:]
# Out:
#    地区    年份  各地村卫生室个数  农村居民教育文化支出占比%  主要农作物粮食产量（万吨）  农业机械总动力（万千瓦）  绿化覆盖面积（公顷）  \
# 0   1  2017      2696            9.1          41.12         133.5      202.99
# 1   1  2018      2493            7.1          34.14         125.7      109.32
# 2   1  2019      2449            9.2          28.76         122.8      155.61
# 3   1  2020      2472            7.1          30.53         120.2      156.61
# 4   1  2021      2559            7.3          37.75         121.2      159.41
#
#       供水普及率%  农村人均住宅建筑面积   设有村镇建设管理机构的个数  有总体规划的乡个数  1000人以上行政村个数  \
# 0  92.140000    45.820000             13         11          1333
# 1  95.975587    45.735534             14         12          1305
# 2  93.885419    49.544809             15         13          1325
# 3  92.783263    48.998163             15         13          1312
# 4  91.143756    52.431180             14         13          1355
#
#    农、林、牧、渔业总产值（亿元）  农村居民人均可支配收入(元)  农村居民人均消费支出(元)
# ...

# %%
new_data = x.iloc[0:5,:].mean().values.reshape(1, -1)
predicted_score = model.predict(new_data)
print('北京预测的综合得分为：', predicted_score)
# Out:
# 北京预测的综合得分为： [0.27985203]

# %%
for i in range(0,155,5):
    new_data = x.iloc[i:i+5,:].mean().values.reshape(1, -1)
    predicted_score = model.predict(new_data)
    print(pred1['地区'][i]+'预测的综合得分为：', predicted_score)
# Out:
# 北京预测的综合得分为： [0.27985203]
# 天津预测的综合得分为： [0.18975784]
# 河北预测的综合得分为： [0.38370519]
# 山西预测的综合得分为： [0.18364848]
# 内蒙古预测的综合得分为： [0.12705138]
# 辽宁预测的综合得分为： [0.09765516]
# 吉林预测的综合得分为： [0.1197156]
# 黑龙江预测的综合得分为： [0.2825961]
# 上海预测的综合得分为： [0.30311055]
# 江苏预测的综合得分为： [0.24223114]
# 浙江预测的综合得分为： [0.30963356]
# 安徽预测的综合得分为： [0.18830613]
# 福建预测的综合得分为： [0.15826595]
# 江西预测的综合得分为： [0.18118566]
# 山东预测的综合得分为： [0.37782208]
# 河南预测的综合得分为： [0.55695931]
# 湖北预测的综合得分为： [0.1642179]
# 湖南预测的综合得分为： [0.27603488]
# 广东预测的综合得分为： [0.17033851]
# 广西预测的综合得分为： [0.16405642]
# 海南预测的综合得分为： [0.11191094]
# 重庆预测的综合得分为： [0.10486616]
# 四川预测的综合得分为： [0.44039679]
# 贵州预测的综合得分为： [0.14008053]
# 云南预测的综合得分为： [0.19775574]
# 西藏预测的综合得分为： [0.12862085]
# 陕西预测的综合得分为： [0.12613876]
# 甘肃预测的综合得分为： [0.11719811]
# 青海预测的综合得分为： [0.11680356]
# 宁夏预测的综合得分为： [0.12259178]
# 新疆预测的综合得分为： [0.1506855]
